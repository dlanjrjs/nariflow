# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
    
'''
import keras
from keras import models
from keras.models import Sequential
from keras.models import Model
from keras.models import load_model
from keras import backend as K
from keras import layers
from keras.layers import Layer
from keras.layers import Input,Dense,Flatten,Embedding,Permute,Dot,Reshape
from keras.layers.convolutional import Conv1D,MaxPooling1D,MaxPooling2D
from keras.layers import Dropout
from keras.layers import LSTM,GRU
from keras.callbacks import Callback
from keras.preprocessing import sequence
from keras.utils import np_utils
'''
 
from nariflow import Variable
from nariflow import optimizer
from nariflow import GradientTape
#from nariflow import calc_gradient
from nariflow import layer
from nariflow.models import Model
from nariflow import functions as f
from nariflow.core import elementary_function as ef
from nariflow.core import shape_function as sf

import tensorflow as tf
from tensorflow.python.framework import function
import math
 
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import roc_auc_score,accuracy_score

#import lightgbm as lgb
 
import scipy

#import statsmodels.api
#import statsmodels as sm
 
import copy
import random
import time
from time import sleep

import re
import os

import networkx as nx

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:90% !important;}</style>"))
# Out:
# <style>.container {width:90% !important;}</style>

# %%
os.listdir("data")
# Out:
# ['179502b7cf14f003d.png',
#  'dangjin_fcst_data.csv',
#  'dangjin_obs_data.csv',
#  'energy.csv',
#  'obs',
#  'OBS_ASOS_TIM_20210509142735.csv',
#  'OBS_ASOS_TIM_20210509143013.csv',
#  'OBS_ASOS_TIM_20210509143059.csv',
#  'OBS_ASOS_TIM_20210525163946.csv',
#  'OBS_ASOS_TIM_20210525164100.csv',
#  'OBS_ASOS_TIM_20210525164127.csv',
#  'OBS_ASOS_TIM_20210526161235.csv',
#  'OBS_ASOS_TIM_20210526161318.csv',
#  'OBS_ASOS_TIM_20210526161340.csv',
#  'OBS_ASOS_TIM_20210526161401.csv',
#  'OBS_ASOS_TIM_20210526161419.csv',
#  'OBS_ASOS_TIM_20210526161438.csv',
#  'sample_submission.csv',
#  'site_info.csv',
#  'ulsan_fcst_data.csv',
#  'ulsan_obs_data.csv',
#  'weather',
#  '석문면_강수형태_201801_201812.csv',
#  '석문면_강수형태_201901_201912.csv',
#  '석문면_강수형태_202001_202012.csv',
#  '석문면_강수형태_202101_202102.csv',
#  '석문면_강수확률_201801_201812.csv',
#  '석문면_강수확률_201901_201912.csv',
#  '석문면_강수확률_202001_202012.csv',
#  '석문면_강수확률_202101_202102.csv',
#  '선암동_강수형태_201801_201812.csv',
#  '선암동_강수형태_201901_201912.csv',
#  '선암동_강수형태_202001_202012.csv',
#  '선암동_강수형태_202101_202102.csv',
#  '선암동_강수확률_201801_201812.csv',
#  '선암동_강수확률_201901_201912.csv',
#  '선암동_강수확률_202001_202012.csv',
#  '선암동_강수확률_202101_202102.csv',
#  '한국동서발전 시간대별 태양광 발전량 현황(2015_2017).csv']

# %% [markdown]
# # 1. Data Load

# %%
dangjin_fcst = pd.read_csv("data/dangjin_fcst_data.csv")
dangjin_obs = pd.read_csv("data/dangjin_obs_data.csv")
energy = pd.read_csv("data/energy.csv")
site_info = pd.read_csv("data/site_info.csv")
ulsan_fcst = pd.read_csv("data/ulsan_fcst_data.csv")
ulsan_obs = pd.read_csv("data/ulsan_obs_data.csv")

# %% [markdown]
# ## 1) 데이터 준비

# %% [markdown]
# ### (1) Forecast Time 변환

# %%
dangjin_fcst["forecast"] = pd.to_datetime(dangjin_fcst["Forecast time"]) + dangjin_fcst["forecast"].apply(
    lambda x : pd.Timedelta(x, unit = "H"))

# %%
ulsan_fcst["forecast"] = pd.to_datetime(ulsan_fcst["Forecast time"]) + ulsan_fcst["forecast"].apply(
    lambda x : pd.Timedelta(x, unit = "H"))

# %% [markdown]
# # 2. EDA

# %% [markdown]
# ## 1) 기초 통계 및 결측, 이상치 확인

# %% [markdown]
# ### (1) 결측치

# %%
print(dangjin_fcst.isna().apply(lambda x : x.value_counts()))
print(dangjin_obs.isna().apply(lambda x : x.value_counts()))
print(energy.isna().apply(lambda x : x.value_counts()))
print(site_info.isna().apply(lambda x : x.value_counts()))
print(ulsan_fcst.isna().apply(lambda x : x.value_counts()))
print(ulsan_obs.isna().apply(lambda x : x.value_counts()))
# Out:
#        Forecast time  forecast  Temperature  Humidity  WindSpeed  \
# False         162208    162208       162208    162208     162208
#
#        WindDirection   Cloud
# False         162208  162208
#             지점      지점명       일시  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  전운량(10분위)
# False  25626.0  25626.0  25626.0   25589    25590     25590  25591      21656
# True       NaN      NaN      NaN      37       36        36     35       3970
#           time  dangjin_floating  dangjin_warehouse  dangjin    ulsan
# False  25632.0             25608              25584  25632.0  25632.0
# True       NaN                24                 48      NaN      NaN
#        Id  Capacity  Address  InstallationAngle  IncidentAngle  Latitude  \
# False   4         4        4                  4              4         4
#
#        Longitude
# False          4
#        Forecast time  forecast  Temperature  Humidity  WindSpeed  \
# False         162208    162208       162208    162208     162208
#
#        WindDirection   Cloud
# False         162208  162208
#             지점      지점명       일시  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  전운량(10분위)
# False  25632.0  25632.0  25632.0   25628    25631     25631  25631      24807
# True       NaN      NaN      NaN       4        1         1      1        825

# %% [markdown]
# Forecast엔 결측치가 없고, obs엔 결측치가 소수 존재한다. Energy 결측치는 이유에 대한 탐색이 필요해보인다.

# %% [markdown]
# #### - Energy 결측 탐색

# %%
energy.loc[energy["dangjin_warehouse"].isna()]
# Out:
#                     time  dangjin_floating  dangjin_warehouse  dangjin  ulsan
# 384   2018-03-17 1:00:00               0.0                NaN        0      0
# 385   2018-03-17 2:00:00               0.0                NaN        0      0
# 386   2018-03-17 3:00:00               0.0                NaN        0      0
# 387   2018-03-17 4:00:00               0.0                NaN        0      0
# 388   2018-03-17 5:00:00               0.0                NaN        0      0
# 389   2018-03-17 6:00:00               0.0                NaN        0      0
# 390   2018-03-17 7:00:00               0.0                NaN        0      0
# 391   2018-03-17 8:00:00              24.0                NaN       16     13
# 392   2018-03-17 9:00:00             162.0                NaN      177     57
# 393  2018-03-17 10:00:00             363.0                NaN      348    206
# 394  2018-03-17 11:00:00             548.0                NaN      532    278
# 395  2018-03-17 12:00:00             689.0                NaN      631    309
# 396  2018-03-17 13:00:00             616.0                NaN      688    366
# 397  2018-03-17 14:00:00             615.0                NaN      706    368
# 398  2018-03-17 15:00:00             689.0                NaN      658    330
# 399  2018-03-17 16:00:00             578.0                NaN      542    272
# 400  2018-03-17 17:00:00             319.0                NaN      272    157
# 401  2018-03-17 18:00:00             139.0                NaN      103     48
# 402  2018-03-17 19:00:00              19.0                NaN        3      3
# 403  2018-03-17 20:00:00               0.0                NaN        0      0
# 404  2018-03-17 21:00:00               0.0                NaN        0      0
# 405  2018-03-17 22:00:00               0.0                NaN        0      0
# 406  2018-03-17 23:00:00               0.0                NaN        0      0
# 407  2018-03-17 24:00:00               0.0                NaN        0      0
# 408   2018-03-18 1:00:00               0.0                NaN        0      0
# 409   2018-03-18 2:00:00               0.0                NaN        0      0
# 410   2018-03-18 3:00:00               0.0                NaN        0      0
# 411   2018-03-18 4:00:00               0.0                NaN        0      0
# 412   2018-03-18 5:00:00               0.0                NaN        0      0
# 413   2018-03-18 6:00:00               0.0                NaN        0      0
# 414   2018-03-18 7:00:00               0.0                NaN        0      0
# 415   2018-03-18 8:00:00               8.0                NaN        0     37
# 416   2018-03-18 9:00:00              36.0                NaN       25    113
# 417  2018-03-18 10:00:00             112.0                NaN      103    199
# 418  2018-03-18 11:00:00             154.0                NaN      137    259
# 419  2018-03-18 12:00:00             219.0                NaN      189    255
# 420  2018-03-18 13:00:00             208.0                NaN      187    300
# 421  2018-03-18 14:00:00             265.0                NaN      223    326
# 422  2018-03-18 15:00:00             168.0                NaN      127    241
# 423  2018-03-18 16:00:00             114.0                NaN       92     91
# 424  2018-03-18 17:00:00             120.0                NaN       99     44
# 425  2018-03-18 18:00:00              24.0                NaN        2     19
# 426  2018-03-18 19:00:00               2.0                NaN        0      0
# 427  2018-03-18 20:00:00               0.0                NaN        0      0
# 428  2018-03-18 21:00:00               0.0                NaN        0      0
# 429  2018-03-18 22:00:00               0.0                NaN        0      0
# 430  2018-03-18 23:00:00               0.0                NaN        0      0
# 431  2018-03-18 24:00:00               0.0                NaN        0      0

# %%
energy.loc[energy["dangjin_floating"].isna()]
# Out:
#                       time  dangjin_floating  dangjin_warehouse  dangjin  \
# 20352   2020-06-26 1:00:00               NaN                0.0        0
# 20353   2020-06-26 2:00:00               NaN                0.0        0
# 20354   2020-06-26 3:00:00               NaN                0.0        0
# 20355   2020-06-26 4:00:00               NaN                0.0        0
# 20356   2020-06-26 5:00:00               NaN                0.0        0
# 20357   2020-06-26 6:00:00               NaN                0.0        0
# 20358   2020-06-26 7:00:00               NaN                7.0        2
# 20359   2020-06-26 8:00:00               NaN               20.0       18
# 20360   2020-06-26 9:00:00               NaN              148.0      175
# 20361  2020-06-26 10:00:00               NaN              242.0      330
# 20362  2020-06-26 11:00:00               NaN              371.0      534
# 20363  2020-06-26 12:00:00               NaN              415.0      590
# 20364  2020-06-26 13:00:00               NaN              484.0      691
# 20365  2020-06-26 14:00:00               NaN              459.0      669
# 20366  2020-06-26 15:00:00               NaN              449.0      647
# 20367  2020-06-26 16:00:00               NaN              380.0      552
# 20368  2020-06-26 17:00:00               NaN              311.0      447
# 20369  2020-06-26 18:00:00               NaN              165.0      253
# 20370  2020-06-26 19:00:00               NaN               37.0       57
# 20371  2020-06-26 20:00:00               NaN                2.0        0
# 20372  2020-06-26 21:00:00               NaN                0.0        0
# 20373  2020-06-26 22:00:00               NaN                0.0        0
# 20374  2020-06-26 23:00:00               NaN                0.0        0
# 20375  2020-06-26 24:00:00               NaN                0.0        0
#
#        ulsan
# 20352      0
# 20353      0
# 20354      0
# 20355      0
# 20356      0
# 20357      0
# 20358      7
# 20359     50
# 20360    161
# 20361    170
# 20362    283
# 20363    318
# 20364    334
# 20365    331
# 20366    303
# 20367    248
# 20368    190
# 20369    101
# 20370     29
# 20371      1
# 20372      0
# 20373      0
# 20374      0
# 20375      0

# %% [markdown]
# Enegry 내부에선 상관성이 있는 변수가 없어보인다.
#
# 정확히 하루 단위로 데이터가 NA이므로, 삭제해도 무방할 것으로 판단됨

# %%
energy = energy.dropna().reset_index(drop = True)

# %% [markdown]
# #### - obs 결측 탐색

# %%
dangjin_obs.isna().apply(lambda x : x.value_counts())
# Out:
#             지점      지점명       일시  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  전운량(10분위)
# False  25626.0  25626.0  25626.0   25589    25590     25590  25591      21656
# True       NaN      NaN      NaN      37       36        36     35       3970

# %%
dangjin_fcst[dangjin_fcst["Forecast time"] == '2019-01-31 11:00:00']
# Out:
#              Forecast time            forecast  Temperature  Humidity  \
# 49728  2019-01-31 11:00:00 2019-01-31 15:00:00         -1.0      40.0
# 49729  2019-01-31 11:00:00 2019-01-31 18:00:00         -3.0      45.0
# 49730  2019-01-31 11:00:00 2019-01-31 21:00:00         -3.0      50.0
# 49731  2019-01-31 11:00:00 2019-02-01 00:00:00         -4.0      50.0
# 49732  2019-01-31 11:00:00 2019-02-01 03:00:00         -2.0      60.0
# 49733  2019-01-31 11:00:00 2019-02-01 06:00:00         -2.0      70.0
# 49734  2019-01-31 11:00:00 2019-02-01 09:00:00         -2.0      70.0
# 49735  2019-01-31 11:00:00 2019-02-01 12:00:00          2.0      45.0
# 49736  2019-01-31 11:00:00 2019-02-01 15:00:00          4.0      45.0
# 49737  2019-01-31 11:00:00 2019-02-01 18:00:00          1.0      65.0
# 49738  2019-01-31 11:00:00 2019-02-01 21:00:00         -2.0      80.0
# 49739  2019-01-31 11:00:00 2019-02-02 00:00:00         -4.0      90.0
# 49740  2019-01-31 11:00:00 2019-02-02 03:00:00          1.0      95.0
# 49741  2019-01-31 11:00:00 2019-02-02 06:00:00          1.0      90.0
# 49742  2019-01-31 11:00:00 2019-02-02 09:00:00          1.0      85.0
# 49743  2019-01-31 11:00:00 2019-02-02 12:00:00          6.0      60.0
# 49744  2019-01-31 11:00:00 2019-02-02 15:00:00          7.0      50.0
# 49745  2019-01-31 11:00:00 2019-02-02 18:00:00          4.0      65.0
# 49746  2019-01-31 11:00:00 2019-02-02 21:00:00          3.0      75.0
# 49747  2019-01-31 11:00:00 2019-02-03 00:00:00          3.0      75.0
#
#        WindSpeed  WindDirection  Cloud
# 49728        9.0          328.0    4.0
# 49729        9.2          323.0    3.0
# 49730       10.9          320.0    3.0
# 49731       10.1          319.0    2.0
# 49732        8.8          320.0    3.0
# 49733        5.9          318.0    3.0
# 49734        2.9          252.0    3.0
# 49735        7.5          284.0    2.0
# 49736        8.1          275.0    2.0
# 49737        7.5          269.0    1.0
# 49738        6.8          262.0    1.0
# 49739        4.4          235.0    1.0
# 49740        3.9          210.0    1.0
# 49741        3.6          214.0    2.0
# 49742        4.4          208.0    2.0
# 49743        5.6          220.0    3.0
# 49744        5.1          208.0    3.0
# 49745        4.8          182.0    3.0
# 49746        4.8          156.0    4.0
# 49747        4.9          127.0    4.0

# %%
dangjin_obs[dangjin_obs["일시"].str.slice(0,10) == '2019-01-31']
# Out:
#        지점 지점명                일시  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  전운량(10분위)
# 8058  129  서산  2019-01-31 00:00     1.4      0.1       0.0   85.0       10.0
# 8059  129  서산  2019-01-31 01:00     1.3      0.4       0.0   87.0       10.0
# 8060  129  서산  2019-01-31 02:00     2.3      1.3      20.0   88.0       10.0
# 8061  129  서산  2019-01-31 03:00     1.8      1.0      20.0   80.0       10.0
# 8062  129  서산  2019-01-31 04:00     1.6      2.5     360.0   56.0       10.0
# 8063  129  서산  2019-01-31 05:00     1.0      1.9     360.0   51.0       10.0
# 8064  129  서산  2019-01-31 06:00     0.6      1.4     360.0   48.0       10.0
# 8065  129  서산  2019-01-31 07:00     0.3      2.9     360.0   48.0       10.0
# 8066  129  서산  2019-01-31 08:00    -0.3      2.4     360.0   45.0       10.0
# 8067  129  서산  2019-01-31 09:00    -0.6      2.7     360.0   44.0       10.0
# 8068  129  서산  2019-01-31 10:00    -0.8      2.4     340.0   42.0       10.0
# 8069  129  서산  2019-01-31 11:00     NaN      NaN       NaN    NaN       10.0
# 8070  129  서산  2019-01-31 12:00     NaN      NaN       NaN    NaN        9.0
# 8071  129  서산  2019-01-31 13:00     NaN      NaN       NaN    NaN       10.0
# 8072  129  서산  2019-01-31 14:00    -0.6      5.3     340.0   42.0       10.0
# 8073  129  서산  2019-01-31 15:00    -0.4      4.7     360.0   40.0        4.0
# 8074  129  서산  2019-01-31 16:00    -1.0      5.1     340.0   39.0        4.0
# 8075  129  서산  2019-01-31 17:00    -1.3      2.6     360.0   42.0        1.0
# 8076  129  서산  2019-01-31 18:00    -2.6      1.5     340.0   43.0        7.0
# 8077  129  서산  2019-01-31 19:00    -3.4      1.5     340.0   46.0        0.0
# 8078  129  서산  2019-01-31 20:00    -3.2      2.2     340.0   49.0        0.0
# 8079  129  서산  2019-01-31 21:00    -3.3      2.5     340.0   49.0        0.0
# 8080  129  서산  2019-01-31 22:00    -3.3      3.8     360.0   45.0        0.0
# 8081  129  서산  2019-01-31 23:00    -3.5      2.3     360.0   45.0        6.0

# %% [markdown]
# 기온, 풍속, 풍향, 습도 결측치는 서로 밀접한 연관이 있는 것으로 보인다.
#
# 활용이 불가능하므로 제외한다.

# %%
dangjin_obs = dangjin_obs.dropna(axis = 0, subset = ["기온(°C)","풍속(m/s)", "풍향(16방위)", "습도(%)"]).reset_index(drop = True)

# %% [markdown]
# ### - 전운량 결측 탐색

# %%
dangjin_obs["전운량(10분위)"].isna().value_counts()
# Out:
# False    21618
# True      3970
# Name: 전운량(10분위), dtype: int64

# %%
dangjin_obs = dangjin_obs.rename(columns = {"일시" : "forecast"})

dangjin_obs["forecast"] = pd.to_datetime(dangjin_obs["forecast"])

# %%
dangjin_obs["date"] = dangjin_obs["forecast"].dt.date
dangjin_obs["hour"] = dangjin_obs["date"].astype("str") + " " + dangjin_obs["forecast"].dt.hour.astype("str")

# %%
# 하루 중 전운량이 NA인 비율

k = dangjin_obs[dangjin_obs["전운량(10분위)"].isna()].groupby("date").apply(lambda x : x["전운량(10분위)"].isna() / len(x))

k.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 최초 예상으로는 전운량이 Na인 경우 하루 전체가 다 그럴것이라는 가설을 세웠지만
#
# 그 가설은 사실이 아닌것으로 판명되었다.

# %%
# 시간 중 전운량이 NA인 비율

k = dangjin_obs[dangjin_obs["전운량(10분위)"].isna()].groupby("hour").apply(lambda x : x["전운량(10분위)"].isna() / len(x))

k.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2) 파생 변수 생성 전략 탐색

# %% [markdown]
# ### (1) obs의 전운량과 fcst의 cloud간 비교

# %% [markdown]
# #### - 데이터 Merge

# %%
result = pd.merge(dangjin_obs, dangjin_fcst, on = "forecast", how = "left")

# %% [markdown]
# #### - 상관계수

# %%
result[["Cloud","전운량(10분위)"]].corr()
# Out:
#              Cloud  전운량(10분위)
# Cloud      1.00000    0.54449
# 전운량(10분위)  0.54449    1.00000

# %% [markdown]
# 상관도가 생각보다 낮다. 예측과 실제값 사이에 괴리감이 큰 것으로 보인다.

# %% [markdown]
# #### - 오차값(잔차) 확인

# %% [markdown]
# 잔차를 확인하면 이를 이용하여 예측값에서 실제 정답값을 유사하게라도 보정할 수 있지 않을까?
#
# 히스토그램을 그려 잔차가 정규분포를 따르는지 확인하고, 실제 정규성 검정을 수행해본다.

# %%
plt.hist(result["Cloud"] - result["전운량(10분위)"])
# Out:
# (array([ 4267., 10232., 22770., 29142.,  9112.,  7611., 13987., 23917.,
#          5448.,  6340.]),
#  array([-9. , -7.7, -6.4, -5.1, -3.8, -2.5, -1.2,  0.1,  1.4,  2.7,  4. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 쌍봉 분포를 보인다.
#
# 차이가 전혀 없는 경우(평균이 0인 정규분포)와 차이가 5~6정도 나는 경우(평균이 5인 정규분포)로 나뉘는 것으로 보인다.

# %%
scipy.stats.kstest((result["Cloud"] - result["전운량(10분위)"]).dropna(), "norm")
# Out:
# KstestResult(statistic=0.6031363661771878, pvalue=0.0)

# %% [markdown]
# 아쉽게도, 잔차는 정규분포를 따르지 않는다.

# %%
result[(result["Cloud"] - result["전운량(10분위)"]) == -5]
# Out:
#          지점 지점명            forecast  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 25226   129  서산 2018-08-03 15:00:00    34.6      3.6     250.0   54.0
# 25227   129  서산 2018-08-03 15:00:00    34.6      3.6     250.0   54.0
# 25228   129  서산 2018-08-03 15:00:00    34.6      3.6     250.0   54.0
# 25229   129  서산 2018-08-03 15:00:00    34.6      3.6     250.0   54.0
# 25230   129  서산 2018-08-03 15:00:00    34.6      3.6     250.0   54.0
# ...     ...  ..                 ...     ...      ...       ...    ...
# 174529  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
# 174538  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
# 174539  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
# 174540  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
# 174541  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
#
#         전운량(10분위)        date           hour        Forecast time  \
# 25226         6.0  2018-08-03  2018-08-03 15  2018-08-01 05:00:00
# 25227         6.0  2018-08-03  2018-08-03 15  2018-08-01 08:00:00
# 25228         6.0  2018-08-03  2018-08-03 15  2018-08-01 11:00:00
# 25229         6.0  2018-08-03  2018-08-03 15  2018-08-01 14:00:00
# 25230         6.0  2018-08-03  2018-08-03 15  2018-08-01 17:00:00
# ...           ...         ...            ...                  ...
# 174529        8.0  2021-01-31  2021-01-31 18  2021-01-30 02:00:00
# 174538        8.0  2021-01-31  2021-01-31 18  2021-01-31 05:00:00
# 174539        8.0  2021-01-31  2021-01-31 18  2021-01-31 08:00:00
# 174540        8.0  2021-01-31  2021-01-31 18  2021-01-31 11:00:00
# 174541        8.0  2021-01-31  2021-01-31 18  2021-01-31 14:00:00
#
#         Temperature  Humidity  WindSpeed  WindDirection  Cloud
# 25226          34.0      55.0        4.1          269.0    1.0
# 25227          34.0      55.0        4.1          269.0    1.0
# 25228          33.0      55.0        4.1          269.0    1.0
# 25229          33.0      55.0        4.1          269.0    1.0
# 25230          33.0      55.0        2.4          294.0    1.0
# ...             ...       ...        ...            ...    ...
# 174529          6.0      75.0        2.9          180.0    3.0
# 174538          6.0      75.0        3.3          168.0    3.0
# 174539          6.0      75.0        3.3          168.0    3.0
# 174540          6.0      75.0        3.3          168.0    3.0
# 174541          6.0      75.0        3.3          168.0    3.0
#
# [16222 rows x 16 columns]

# %%
result["Cloud"].hist()
# Out:
# <AxesSubplot:>

# %%
result[(result["Cloud"] - result["전운량(10분위)"]) == -5]["Cloud"].hist()
# Out:
# <AxesSubplot:>

# %%
result[(result["Cloud"] - result["전운량(10분위)"]) == -5]["전운량(10분위)"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 전운량의 예측은 1 ~ 4밖에 없다.
#
# 예측 오차가 크게 나는 경우는 실제 전운량이 6 이상으로 나타나는 경우였다.

# %%
dangjin_fcst.describe()
# Out:
#          Temperature       Humidity      WindSpeed  WindDirection  \
# count  162208.000000  162208.000000  162208.000000  162208.000000
# mean       12.624634      76.996147       3.639262     214.147761
# std         9.816256      17.435418       2.627592     108.020035
# min       -14.000000       5.000000       0.000000       0.000000
# 25%         4.000000      65.000000       1.900000     115.000000
# 50%        13.000000      80.000000       2.800000     237.000000
# 75%        21.000000      90.000000       4.600000     313.000000
# max        36.000000     100.000000      32.299999     360.000000
#
#                Cloud
# count  162208.000000
# mean        2.439411
# std         1.214753
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000

# %% [markdown]
# ## 2) 변수 선별

# %% [markdown]
# ### (1) 변수 선별용 데이터 전처리

# %% [markdown]
# #### - X, y 데이터 생성

# %%
temp = DataFrame(list(DataFrame(list(energy["time"].str.split(" ")))[1].str.split(":")))

# %%
energy["time"] = pd.to_datetime(
    DataFrame(list(energy["time"].str.split(" ")))[0] + 
    " " 
    + (temp[0].astype("int") - 1).astype("str") + ":" + temp[1] + ":" + temp[2])

# %%
energy_obs = pd.merge(energy, dangjin_obs, left_on = "time", right_on = "forecast", how = "left")

# %%
energy_obs = energy_obs.dropna().reset_index(drop = True)

energy_obs = energy_obs.drop(["date","hour", "지점", "지점명", "forecast"], axis = 1)

# %% [markdown]
# #### - 일출 일몰 정보 생성

# %%
def day_night(x):
    if x < 6 or x > 18:
        return 0
    else:
        return 1

# %%
energy_obs["day_night"] = energy_obs["time"].dt.hour.apply(lambda x : day_night(int(x)))

# %% [markdown]
# # 3. 데이터 전처리

# %% [markdown]
# ## 1) 결측값 대체

# %% [markdown]
# ### (1) fcst 보간

# %% [markdown]
# #### - spline 보간

# %%
energy['time'] = energy['time'].astype('str')

# %%
temp = DataFrame(list(DataFrame(list(energy["time"].str.split(" ")))[1].str.split(":")))

energy["time"] = pd.to_datetime(
    DataFrame(list(energy["time"].str.split(" ")))[0] + 
    " " 
    + (temp[0].astype("int") - 1).astype("str") + ":" + temp[1] + ":" + temp[2])

energy = energy.dropna().reset_index(drop = True)

# %%
def time_interpolate(x, data):
    
    temp = data[data["time"].dt.date == x].drop_duplicates("time", keep = "last")
    
    min_time = np.min(temp["time"])
    
    max_time = min_time + pd.Timedelta(hours = 23)
    
    time_index = pd.date_range(min_time, max_time, freq = "H")
    
    temp = pd.merge(pd.Series(pd.date_range(min_time, max_time, freq = "H"),name = "time"),
         temp,
         how = "left")
    
    return temp

# %%
dangjin_fcst = dangjin_fcst.dropna(axis = 0, subset = ["Temperature","Humidity", "WindSpeed", "WindDirection"]).reset_index(drop = True)

dangjin_fcst["Forecast time"] = pd.to_datetime(dangjin_fcst["Forecast time"])

dangjin_fcst = dangjin_fcst.rename(columns = {"forecast":"time"})

result = pd.Series(dangjin_fcst["time"].dt.date.unique()).apply(lambda x : time_interpolate(x, dangjin_fcst))

dangjin_fcst = pd.concat(list(result))

del dangjin_fcst["Forecast time"]

dangjin_fcst = dangjin_fcst.drop_duplicates("time").reset_index(drop = True)

# %%
dangjin_fcst.iloc[:,1:] = dangjin_fcst.iloc[:,1:].apply(lambda x : x.interpolate(method = "spline", order = 2))

# %%
ulsan_fcst = ulsan_fcst.dropna(axis = 0, subset = ["Temperature","Humidity", "WindSpeed", "WindDirection"]).reset_index(drop = True)

ulsan_fcst["Forecast time"] = pd.to_datetime(ulsan_fcst["Forecast time"])

ulsan_fcst = ulsan_fcst.rename(columns = {"forecast":"time"})

result = pd.Series(ulsan_fcst["time"].dt.date.unique()).apply(lambda x : time_interpolate(x, ulsan_fcst))

ulsan_fcst = pd.concat(list(result))

del ulsan_fcst["Forecast time"]

ulsan_fcst = ulsan_fcst.drop_duplicates("time").reset_index(drop = True)

# %%
ulsan_fcst.iloc[:,1:] = ulsan_fcst.iloc[:,1:].apply(lambda x : x.interpolate(method = "spline", order = 2))

# %% [markdown]
# ## 2) 파생 변수 생성

# %% [markdown]
# ### (1) day_night 변수 추가

# %%
def day_night(x):
    if x < 5 or x > 19:
        return 0
    else:
        return 1

# %%
dangjin_fcst["day_night"] = dangjin_fcst["time"].dt.hour.apply(lambda x : day_night(int(x)))

# %%
ulsan_fcst["day_night"] = ulsan_fcst["time"].dt.hour.apply(lambda x : day_night(int(x)))

# %% [markdown]
# ### (2) 월 변수 추가

# %% [markdown]
# #### - dangjin

# %%
temp = pd.DataFrame(dangjin_fcst["time"]).copy()

# %%
temp["month"] = dangjin_fcst["time"].dt.month
temp["year"] = dangjin_fcst["time"].dt.year
temp["year"] = temp["year"].apply(lambda x : int(np.where(temp["year"].unique() == x)[0]))
temp["day"] = dangjin_fcst["time"].dt.day

temp["hour"] = dangjin_fcst["time"].dt.hour

# %%
dangjin_fcst = pd.merge(dangjin_fcst, temp, how = "left")

# %%
energy_fcst_dangjin = pd.merge(energy, dangjin_fcst).dropna()

# %% [markdown]
# #### - ulsan

# %%
temp = pd.DataFrame(ulsan_fcst["time"]).copy()

# %%
temp["month"] = ulsan_fcst["time"].dt.month
temp["year"] = ulsan_fcst["time"].dt.year
temp["year"] = temp["year"].apply(lambda x : int(np.where(temp["year"].unique() == x)[0]))
temp["day"] = ulsan_fcst["time"].dt.day

temp["hour"] = ulsan_fcst["time"].dt.hour

# %%
ulsan_fcst = pd.merge(ulsan_fcst, temp)

# %%
energy_fcst_ulsan = pd.merge(energy, ulsan_fcst, how = "left").dropna()

# %% [markdown]
# # 4. 모델링

# %% [markdown]
# ## 1) train_test 분할

# %% [markdown]
# ### (1) 당진 분할

# %%
temp = DataFrame(energy_fcst_dangjin["time"].dt.date)

# %%
def gen():
    n = 0
    while True:
        n += 1
        yield n
        
num = gen()

# %%
temp = temp.groupby("time").apply(lambda x : next(num))

temp = temp.reset_index(name = "num")
temp.columns = ["date","num"]

energy_fcst_dangjin["date"] = energy_fcst_dangjin["time"].dt.date

energy_fcst_dangjin = pd.merge(energy_fcst_dangjin, temp)

k = energy_fcst_dangjin.groupby("num").apply(lambda x : len(x) / 24)

k = k.reset_index(name = "ratio")

k_full = DataFrame(list(set(k["num"]).difference(set(k.loc[k["ratio"] < 1, "num"]))),
         columns = ["num"])

energy_fcst_dangjin = pd.merge(k_full, 
         energy_fcst_dangjin,
         how = "left")

#train_num = np.random.choice(energy_fcst_dangjin["num"].unique(),
#              size = int(len(energy_fcst_dangjin["num"].unique()) * 0.75),
#                replace = False)

train_num = [i for i in range(0, len(energy_fcst_dangjin["num"].unique()) - 30)]

test_num = [i for i in range(len(energy_fcst_dangjin["num"].unique()) - 30, 
                            len(energy_fcst_dangjin["num"].unique()))]

train = pd.merge(DataFrame(train_num, columns = ["num"]), energy_fcst_dangjin)

test = pd.merge(DataFrame(test_num, columns = ["num"]), energy_fcst_dangjin)

X_train_dangjin = train[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "month",
                         "year",
                         "day",
                         "hour",
                         "num"]]

X_train_dangjin = X_train_dangjin.groupby('num').apply(lambda x : x[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "month",
                         "year",
                         "day",
                         "hour",]].to_numpy())

X_test_dangjin = test[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "month",
                         "year",
                         "day",
                         "hour",
                       "num"]]

X_test_dangjin = X_test_dangjin.groupby('num').apply(lambda x : x[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "month",
                         "year",
                         "day",
                         "hour",]].to_numpy())

X_train_dangjin = np.stack(X_train_dangjin)
X_test_dangjin = np.stack(X_test_dangjin)

# %%
y_train_dangjin = train[["num","dangjin"]]
y_test_dangjin = test[["num","dangjin"]]

y_train_dangjin = np.stack(y_train_dangjin.groupby("num").apply(lambda x : np.array(x["dangjin"])))
y_test_dangjin = np.stack(y_test_dangjin.groupby("num").apply(lambda x : np.array(x["dangjin"])))

# %%
y_train_dangjin_ware = train[["num","dangjin_warehouse"]]
y_test_dangjin_ware = test[["num","dangjin_warehouse"]]

y_train_dangjin_ware = np.stack(y_train_dangjin_ware.groupby("num").apply(lambda x : np.array(x["dangjin_warehouse"])))
y_test_dangjin_ware = np.stack(y_test_dangjin_ware.groupby("num").apply(lambda x : np.array(x["dangjin_warehouse"])))

# %%
y_train_dangjin_float = train[["num","dangjin_floating"]]
y_test_dangjin_float = test[["num","dangjin_floating"]]

y_train_dangjin_float = np.stack(y_train_dangjin_float.groupby("num").apply(lambda x : np.array(x["dangjin_floating"])))
y_test_dangjin_float = np.stack(y_test_dangjin_float.groupby("num").apply(lambda x : np.array(x["dangjin_floating"])))

# %% [markdown]
# ### (2) 울산 분할

# %%
temp = DataFrame(energy_fcst_ulsan["time"].dt.date)

# %%
temp = temp.groupby("time").apply(lambda x : next(num))

temp = temp.reset_index(name = "num")
temp.columns = ["date","num"]

energy_fcst_ulsan["date"] = energy_fcst_ulsan["time"].dt.date

energy_fcst_ulsan = pd.merge(energy_fcst_ulsan, temp)

k = energy_fcst_ulsan.groupby("num").apply(lambda x : len(x) / 24)

# %%
k = k.reset_index(name = "ratio")

k_full = DataFrame(list(set(k["num"]).difference(set(k.loc[k["ratio"] < 1, "num"]))),
         columns = ["num"])

energy_fcst_ulsan = pd.merge(k_full, 
         energy_fcst_ulsan,
         how = "left")

#train_num = np.random.choice(energy_fcst_dangjin["num"].unique(),
#              size = int(len(energy_fcst_dangjin["num"].unique()) * 0.75),
#                replace = False)

train_num = [i for i in range(np.min(energy_fcst_ulsan["num"].unique()), 
                              np.max(energy_fcst_ulsan["num"].unique()) - 30)]

test_num = [i for i in range(np.max(energy_fcst_ulsan["num"].unique()) - 30, 
                            np.max(energy_fcst_ulsan["num"].unique()) + 1)]

train = pd.merge(DataFrame(train_num, columns = ["num"]), energy_fcst_ulsan)

test = pd.merge(DataFrame(test_num, columns = ["num"]), energy_fcst_ulsan)

X_train_ulsan = train[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "year",
                         "month",
                         "day",
                         "hour",
                         "num"]]

X_train_ulsan = X_train_ulsan.groupby('num').apply(lambda x : x[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "year",
                         "month",
                         "day",
                         "hour",]].to_numpy())

X_test_ulsan = test[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "year",
                         "month",
                         "day",
                         "hour",
                       "num"]]

X_test_ulsan = X_test_ulsan.groupby('num').apply(lambda x : x[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "year",
                         "month",
                         "day",
                         "hour",]].to_numpy())

X_train_ulsan = np.stack(X_train_ulsan)
X_test_ulsan = np.stack(X_test_ulsan)

# %%
y_train_ulsan = train[["num","ulsan"]]
y_test_ulsan = test[["num","ulsan"]]

y_train_ulsan = np.stack(y_train_ulsan.groupby("num").apply(lambda x : np.array(x["ulsan"])))
y_test_ulsan = np.stack(y_test_ulsan.groupby("num").apply(lambda x : np.array(x["ulsan"])))

# %% [markdown]
# ### 1) RNN testing

# %% [markdown]
# ### (1) min_max_scale

# %%
train_min_dangjin = np.min(X_train_dangjin)
train_max_dangjin = np.max(X_train_dangjin)

X_train_dangjin_scaled = (X_train_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

X_test_dangjin_scaled = (X_test_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

#X_train_dangjin_scaled[:,:,4] = X_train_dangjin[:,:,4]

#X_test_dangjin_scaled[:,:,4] = X_test_dangjin[:,:,4]

# %%
y_train_dangjin_scaled = (y_train_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_scaled = (y_test_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %%
y_train_dangjin_ware_scaled = (y_train_dangjin_ware - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_ware_scaled = (y_test_dangjin_ware - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %%
y_train_dangjin_float_scaled = (y_train_dangjin_float - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_float_scaled = (y_test_dangjin_float - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %% [markdown]
# #### - nariflow  테스트

# %%
EPOCHS = 200
batch_size = 50

# %%
class SimpleRNN(Model):
    def __init__(self, hidden_size, out_size):
        super().__init__()
        self.l1 = layer.RNN(hidden_size)
        #self.l2 = layer.LSTM(int(hidden_size / 2))
        #self.l3 = layer.LSTM(hidden_size)
        self.l4 = layer.Linear(out_size, initializer_func='he_uniform')
        
    def forward(self, x):
        y = self.l1(x)
        #y = self.l2(y)
        #y = self.l3(y)
        y = self.l4(y)
        return y

# %%
capacity = 1000
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()
 
model = SimpleRNN(100, 1)
optimizers = optimizer.Adam(0.001)
optimizers.setup(model)
    
for epoch in range(EPOCHS):

    for mini in range(1, int(X_train_dangjin_scaled.shape[0] / batch_size) + 2):
        inp = Variable(X_train_dangjin_scaled[(mini - 1) * batch_size : (mini * batch_size)][:,:23,:])
        tar = Variable(y_train_dangjin_scaled[(mini - 1) * batch_size : (mini * batch_size)][:,1:])

        for teps in range(inp.shape()[1]):
            with GradientTape() as tape:    
                y_pred = model(inp[:,teps,:])
                loss = f.loss.mean_squared_error(sf.reshape(y_pred, [-1]), tar[:,teps])
            tape.CalcGradient()
            optimizers.update()
            model.l1.reset_state()
            #model.l2.reset_state()
            #model.l3.reset_state()

        if epoch % 10 == 0:
            print(loss.data)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {loss} Accuracy ')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
# Out:
# 2.624374472276535
# 1.3558199972835978
# 2.619437959525888
# 2.4709422607933673
# 2.027205403546853
# 1.277172894210943
# 1.0956454130906836
# 1.8425347517966932
# 2.385848299684769
# 2.584942065911904
# 2.252976272348673
# 1.479090003499954
# 0.9968545500055164
# 0.7480687461044735
# 0.8585801962125827
# 1.6372851776618194
# 2.278743970878712
# 1.5694853017122536
# 1.4687263711039664
# 1.3642802294030425
# 1.094594125258249
# 1.0005195601527253
# 1.4684568407231557
# 1.8816584106018275
# 1.8741335565996768
# 1.5670148954871248
# 1.1589755336279297
# 1.2115746170865442
# 1.4578679147366598
# 2.2431244793329106
# 2.0817955697138664
# 1.8715206579775638
# 1.2177619582083694
# 0.8814467523561
# 0.6387467641362065
# 0.9246263869776442
# 2.120570183496028
# 1.8724015868305144
# 1.2099163504612922
# 1.6233952704040622
# 1.4267355022851655
# 0.9347675355303957
# 0.7358774050451463
# 1.1593699466754641
# 1.477266599046385
# 1.4103174766627973
# 1.0994741424330436
# 0.8175112011421329
# 0.9886846133244283
# 1.1049814630859744
# 1.9207709335575305
# 1.6397108676634742
# 1.409610583969159
# 0.8672319475140672
# 0.6245031635108059
# 0.4380850081202445
# 0.74220464424611
# 1.880702798626985
# 1.4297947210271633
# 0.8522613499175321
# 1.3322167637578854
# 1.153495945518047
# 0.6754978029171776
# 0.6102129422132768
# 0.9785379255698357
# 1.2378985843149757
# 1.1515047745323383
# 0.8509512848980357
# 0.63818605206094
# 0.8509511424512024
# 0.9093262131592375
# 1.7127703715904883
# 1.4040457602482985
# 1.1679990792786594
# 0.6898115244371195
# 0.4878315342845305
# 0.33872706472116276
# 0.6298910163133299
# 1.6829489938292508
# 1.1891450828971386
# 0.6666242597924519
# 1.1420138526569932
# 0.9858912932769525
# 0.5322114518081724
# 0.5504841628768216
# 0.8800331925996657
# 1.101459013989557
# 1.0027082993774672
# 0.7105005381589424
# 0.5408048423086591
# 0.777890630179094
# 0.8025307242078504
# 1.6004836593071747
# 1.2840982183012353
# 1.042928114449841
# 0.6005587837580888
# 0.41942316359058956
# 0.29374187046075856
# 0.5702047002495026
# 1.5611132069269058
# 1.0558726028098955
# 0.568946224443184
# 1.0362815339401374
# 0.8972489877882586
# 0.4569392902007286
# 0.5226672531128649
# 0.8261952191463547
# 1.0219330396564947
# 0.9134055493406311
# 0.6253916458664822
# 0.48386456959389434
# 0.738695212925611
# 0.7422362941211168
# 1.5420650355097052
# 1.2243805927286693
# 0.9773778748457636
# 0.5544261455224385
# 0.3840894781255231
# 0.2738673755754963
# 0.5389514478502089
# 1.4882309902242046
# 0.9792490706113304
# 0.5147304202139984
# 0.9779433804724598
# 0.8510623515631902
# 0.4161082247119509
# 0.5098909417338303
# 0.7950881264559867
# 0.9721779596963462
# 0.8550773316428498
# 0.5687574771349372
# 0.4467992897827792
# 0.7160328681053835
# 0.7049160529392402
# 1.5101527430106905
# 1.1932614810070998
# 0.9407042605947639
# 0.5287216301847595
# 0.36439976156479004
# 0.26518498868753454
# 0.5220478025887328
# 1.4429063986511506
# 0.9316910192025809
# 0.4820151545047057
# 0.9425323318570649
# 0.8259082336085817
# 0.3918615372398218
# 0.5042053226456212
# 0.7758771045499699
# 0.9383139464306247
# 0.8137756950120525
# 0.5283381055368339
# 0.4204433132626965
# 0.7014034990825506
# 0.6795490159517098
# 1.4914236558479608
# 1.1764325328893672
# 0.9187714397876156
# 0.5135069295955088
# 0.3527526307452086
# 0.2618345796821367
# 0.5127296220902409
# 1.413061419500656
# 0.8991029876591083
# 0.4596683348021078
# 0.9202568578778073
# 0.811297386474576
# 0.3764476181417403
# 0.5026490619580801
# 0.7639851598782077
# 0.9141220056157716
# 0.7827930254108595
# 0.4975453904052505
# 0.4014802900625768
# 0.6924996576767043
# 0.6624243468834673
# 1.4800535850207022
# 1.167587442645406
# 0.9052963994629003
# 0.5040471610489501
# 0.3455453578825335
# 0.2612266038077312
# 0.5077613130007019
# 1.3921857641677358
# 0.8752533810880517
# 0.4430593284340992
# 0.9043459102853079
# 0.8023824965351597
# 0.3659764915022964
# 0.5027301628109561
# 0.7556591412479642
# 0.8953552911618695
# 0.7581603837763946
# 0.4731659238062796
# 0.385821625589627
# 0.684998321736235
# 0.6483712668798521
# 1.471612879761369
# 1.1620897236032448
# 0.8956933843222501
# 0.4973242094530622
# 0.34046619177071713
# 0.2614980708986362
# 0.5046540728193863
# 1.3764433726614214
# 0.856438574511004
# 0.42959643370515943
# 0.8918328667152209
# 0.7963760657751432
# 0.3581652977775017
# 0.5035469174070556
# 0.7494256031261902
# 0.8800843453471778
# 0.7375697092964626
# 0.452600111259803
# 0.3730719271677871
# 0.6787912300411576
# 0.6368018398930482
# 1.4645532423113892
# 1.1576654551763392
# 0.8878206621669009
# 0.4918967245419977
# 0.3363948132202793
# 0.2619450741039226
# 0.5024586321044173
# 1.3638579325748994
# 0.8407729724818479
# 0.4180732668334817
# 0.8814454460602541
# 0.791661783028468
# 0.3517967223349892
# 0.5046235575856031
# 0.7444070859747941
# 0.8671477871613464
# 0.7200994654230919
# 0.4351072805659205
# 0.36178753414467757
# 0.6726620241290902
# 0.6260705602784447
# 1.457898665262361
# 1.1537287062581982
# 0.8809001646112944
# 0.48721459408580875
# 0.33292725144593915
# 0.26236657426020593
# 0.5007448561196925
# 1.3534576158069418
# 0.8273511877348522
# 0.4079359024648964
# 0.8725645958142876
# 0.7879127265156997
# 0.3465164216217191
# 0.5059011516657904
# 0.7402838461660862
# 0.8560726958817806
# 0.7049049991614609
# 0.4201150006233402
# 0.3519168231315526
# 0.6670573653696096
# 0.6164513227892902
# 1.45169766436065
# 1.1502408640236959
# 0.8748372295211999
# 0.48325858169572783
# 0.33003640552663255
# 0.2628587358425594
# 0.4994620266356122
# 1.3447019314545208
# 0.8157826191048412
# 0.39904453074597357
# 0.8647519042923928
# 0.7849195095634056
# 0.34205763333718187
# 0.5075168384715236
# 0.7371068259468267
# 0.846614821626807
# 0.6914952359318689
# 0.4069512069474954
# 0.3436037360218225
# 0.6625786243510504
# 0.6084296258340359
# 1.446113421666288
# 1.1471233208936833
# 0.869586180176921
# 0.47996655744158284
# 0.32765391137072447
# 0.26346362938631795
# 0.49860524648821103
# 1.3372863128871268
# 0.8057727514675845
# 0.391208505813239
# 0.857937639874351
# 0.7824823819426233
# 0.3382826211491102
# 0.5094268442567287
# 0.7347915857582293
# 0.8386233697513503
# 0.6801176360440819
# 0.3957015144484027
# 0.3362935783297445
# 0.6581538669945937
# 0.6010212167069856
# 1.4405977327975146
# 1.1443801786097045
# 0.865066110851636
# 0.47726363660344684
# 0.3257649963195878
# 0.2642106153340068
# 0.4981860738469085
# 1.3311045904067296
# 0.7971746555800643
# 0.38431387825671015
# 0.8518401419006726
# 0.7806359141088144
# 0.335138680064366
# 0.5115859928399707
# 0.733237659501245
# 0.8318890730967544
# 0.6699966522591768
# 0.38606211327712353
# 0.3301358980862757
# 0.6548737555283427
# 0.5950726784324702
# 1.4360648389138402
# 1.142574802332941
# 0.8616989771714512
# 0.4752737336904693
# 0.32433406011271715
# 0.26507980205448367
# 0.4981377971605548
# 1.3259831003638936
# 0.7898047285142958
# 0.37824868401363365
# 0.8464360757791738
# 0.7791368231519518
# 0.3324120384689199
# 0.513750087382936
# 0.7321123627475288
# 0.8261384929816518
# 0.6613649292712774
# 0.37774645901931636
# 0.3246779206370939
# 0.6515228884242901
# 0.5895254483169766
# 1.4315444099901853
# 1.1408839026162718
# 0.8588412891363534
# 0.4736704109669776
# 0.32318630713257135
# 0.2659409862996136
# 0.4983136621338416
# 1.3217553964588038
# 0.783530012151478
# 0.37297646201041723
# 0.8417698317326732
# 0.7778837621252476
# 0.33002132480932467
# 0.5158428306758193
# 0.7311419478448161
# 0.8211374388688895
# 0.6533501398525019
# 0.3697902375403689
# 0.3202577346319934
# 0.6493572806018361
# 0.5851831820838884
# 1.427961726309536
# 1.1395923583138836
# 0.8565081477246888
# 0.47251669315902844
# 0.32236438788417116
# 0.26680911342256164
# 0.49864674776079154
# 1.3183220239735756
# 0.7781206926945136
# 0.36842991659635627
# 0.837846164560111
# 0.7770213831922967
# 0.327974170929843
# 0.5179528999397327
# 0.73040127225349
# 0.8166484251073797
# 0.6464995544786539
# 0.36304231254964003
# 0.3156814807765373
# 0.6463555978717623
# 0.5801933066148014
# 1.4236947920261445
# 1.1377400985766968
# 0.8538984275045949
# 0.4712806914309195
# 0.3216086442317885
# 0.26755310378276986
# 0.49901826122136883
# 1.3155131329621557
# 0.7734223268849223
# 0.36445040679144286
# 0.8343309942799606
# 0.7766036940007182
# 0.3263271430250017
# 0.5199536330398313
# 0.7298136061321218
# 0.8126131680280152
# 0.6399188140591459
# 0.3565156645287487
# 0.31198280421675495
# 0.6443823788281392
# 0.5762888362117343
# 1.4205933482420292
# 1.136279787461178
# 0.8519193545454193
# 0.4703725140183941
# 0.3209058025714817
# 0.2681782416214268
# 0.4994662138650003
# 1.3131497708673137
# 0.769106294383525
# 0.36080239892206634
# 0.8315193720870033
# 0.7760523762590376
# 0.32476956215415254

# %%
pred_result = list()
for teps in range(inp.shape()[1]):
    pred_result.append(model(inp[0,teps,:]))
    model.l1.reset_state()

# %%
[i.data for i in pred_result]
# Out:
# [array([1.37163332]),
#  array([1.37163332]),
#  array([1.48216976]),
#  array([1.18543139]),
#  array([1.02617607]),
#  array([0.85751949]),
#  array([0.79833739]),
#  array([0.74574105]),
#  array([0.87138087]),
#  array([0.88490444]),
#  array([0.86492471]),
#  array([0.84181108]),
#  array([0.85555068]),
#  array([0.81464297]),
#  array([0.99146444]),
#  array([1.11901712]),
#  array([1.28614277]),
#  array([1.41106554]),
#  array([1.40731971]),
#  array([1.20788487]),
#  array([1.10352936]),
#  array([0.97813417]),
#  array([0.93915772])]

# %% [markdown]
# ### - 텐서플로우 테스트

# %%
class TrainModel(tf.keras.Model):
    def __init__(self, 
                 kernel_size, 
                 lstm_dim):
        
        super(TrainModel, self).__init__()

        self.kernel_size = kernel_size
        self.lstm_dim = lstm_dim
     
    def build(self, input_shape):
        
        self.lstm = tf.keras.layers.SimpleRNN(self.lstm_dim,
                                        return_sequences = True)
        
        output_layer = tf.keras.layers.Dense(1, activation = "relu")
        
        self.outputs = tf.keras.layers.TimeDistributed(output_layer)
    
    def call(self, input_tensor):
        
        lstm_output_1 = self.lstm(input_tensor)
        
        output = self.outputs(lstm_output_1)
        
        return output

# %%
Models_dangjin = TrainModel(
                     kernel_size = 200, 
                      lstm_dim = 100)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
@tf.function()
def train_step_dangjin(inp , tar):
    with tf.GradientTape() as tape:
        
        output = Models_dangjin(inp)

        loss =  loss_function(tar, output)
    
    gradients = tape.gradient(loss, Models_dangjin.trainable_variables)
    optimizer_tf.apply_gradients(zip(gradients, Models_dangjin.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
def val_accuracy(inp, tar, Models):
    output = Models(inp)
    
    test_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
capacity = 1000
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()


train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
optimizer_tf = tf.keras.optimizers.Adam()

for epoch in range(EPOCHS):
    train_loss.reset_state()
    start = time.time()   
    i = 1
    while True:

        inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_dangjin(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_dangjin_scaled, y_test_dangjin_ware_scaled, Models_dangjin)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 3.9741 Accuracy 33.9377
# Epoch 1 Batch 10 Loss 3.3436 Accuracy 28.2974
# Epoch 1 Batch 15 Loss 2.6271 Accuracy 24.0171
# Epoch 1 Batch 20 Loss 2.2823 Accuracy 22.3131
# Time taken for 1 epoch: 0.81 secs
#
# TestLoss 0.0000 TestAccuracy 13.4541
# Epoch 2 Batch 5 Loss 1.0763 Accuracy 20.8079
# Epoch 2 Batch 10 Loss 1.0808 Accuracy 19.7027
# Epoch 2 Batch 15 Loss 1.0923 Accuracy 18.6789
# Epoch 2 Batch 20 Loss 1.1172 Accuracy 18.3493
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.4411
# Epoch 3 Batch 5 Loss 1.1061 Accuracy 18.1208
# Epoch 3 Batch 10 Loss 1.0559 Accuracy 17.8756
# Epoch 3 Batch 15 Loss 1.0776 Accuracy 17.4056
# Epoch 3 Batch 20 Loss 1.1033 Accuracy 17.2439
# Time taken for 1 epoch: 0.15 secs
#
# TestLoss 0.0000 TestAccuracy 13.8006
# Epoch 4 Batch 5 Loss 0.9975 Accuracy 17.0458
# Epoch 4 Batch 10 Loss 1.0258 Accuracy 16.9602
# Epoch 4 Batch 15 Loss 1.0514 Accuracy 16.6835
# Epoch 4 Batch 20 Loss 1.0706 Accuracy 16.6102
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.9511
# Epoch 5 Batch 5 Loss 0.9857 Accuracy 16.4919
# Epoch 5 Batch 10 Loss 1.0160 Accuracy 16.4427
# Epoch 5 Batch 15 Loss 1.0494 Accuracy 16.2441
# Epoch 5 Batch 20 Loss 1.0587 Accuracy 16.1907
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.9944
# Epoch 6 Batch 5 Loss 0.9929 Accuracy 16.1243
# Epoch 6 Batch 10 Loss 1.0168 Accuracy 16.1018
# Epoch 6 Batch 15 Loss 1.0474 Accuracy 15.9504
# Epoch 6 Batch 20 Loss 1.0528 Accuracy 15.9095
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 14.0302
# Epoch 7 Batch 5 Loss 0.9896 Accuracy 15.8652
# Epoch 7 Batch 10 Loss 1.0116 Accuracy 15.8542
# Epoch 7 Batch 15 Loss 1.0420 Accuracy 15.7331
# Epoch 7 Batch 20 Loss 1.0472 Accuracy 15.7044
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 14.0510
# Epoch 8 Batch 5 Loss 0.9870 Accuracy 15.6742
# Epoch 8 Batch 10 Loss 1.0067 Accuracy 15.6690
# Epoch 8 Batch 15 Loss 1.0386 Accuracy 15.5682
# Epoch 8 Batch 20 Loss 1.0433 Accuracy 15.5473
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 14.0540
# Epoch 9 Batch 5 Loss 0.9862 Accuracy 15.5270
# Epoch 9 Batch 10 Loss 1.0032 Accuracy 15.5255
# Epoch 9 Batch 15 Loss 1.0369 Accuracy 15.4393
# Epoch 9 Batch 20 Loss 1.0404 Accuracy 15.4229
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 14.0480
# Epoch 10 Batch 5 Loss 0.9858 Accuracy 15.4093
# Epoch 10 Batch 10 Loss 1.0003 Accuracy 15.4102
# Epoch 10 Batch 15 Loss 1.0356 Accuracy 15.3351
# Epoch 10 Batch 20 Loss 1.0375 Accuracy 15.3212
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 14.0389
# Epoch 11 Batch 5 Loss 0.9850 Accuracy 15.3121
# Epoch 11 Batch 10 Loss 0.9978 Accuracy 15.3146
# Epoch 11 Batch 15 Loss 1.0341 Accuracy 15.2483
# Epoch 11 Batch 20 Loss 1.0344 Accuracy 15.2360
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 14.0307
# Epoch 12 Batch 5 Loss 0.9833 Accuracy 15.2298
# Epoch 12 Batch 10 Loss 0.9951 Accuracy 15.2335
# Epoch 12 Batch 15 Loss 1.0317 Accuracy 15.1741
# Epoch 12 Batch 20 Loss 1.0307 Accuracy 15.1630
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 14.0240
# Epoch 13 Batch 5 Loss 0.9813 Accuracy 15.1588
# Epoch 13 Batch 10 Loss 0.9922 Accuracy 15.1630
# Epoch 13 Batch 15 Loss 1.0286 Accuracy 15.1092
# Epoch 13 Batch 20 Loss 1.0267 Accuracy 15.0991
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 14.0182
# Epoch 14 Batch 5 Loss 0.9793 Accuracy 15.0964
# Epoch 14 Batch 10 Loss 0.9892 Accuracy 15.1010
# Epoch 14 Batch 15 Loss 1.0253 Accuracy 15.0517
# Epoch 14 Batch 20 Loss 1.0226 Accuracy 15.0424
# Time taken for 1 epoch: 0.15 secs
#
# TestLoss 0.0000 TestAccuracy 14.0122
# Epoch 15 Batch 5 Loss 0.9777 Accuracy 15.0410
# Epoch 15 Batch 10 Loss 0.9863 Accuracy 15.0456
# Epoch 15 Batch 15 Loss 1.0219 Accuracy 15.0000
# Epoch 15 Batch 20 Loss 1.0186 Accuracy 14.9913
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 14.0053
# Epoch 16 Batch 5 Loss 0.9763 Accuracy 14.9910
# Epoch 16 Batch 10 Loss 0.9835 Accuracy 14.9956
# Epoch 16 Batch 15 Loss 1.0186 Accuracy 14.9532
# Epoch 16 Batch 20 Loss 1.0149 Accuracy 14.9450
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.9980
# Epoch 17 Batch 5 Loss 0.9743 Accuracy 14.9455
# Epoch 17 Batch 10 Loss 0.9800 Accuracy 14.9500
# Epoch 17 Batch 15 Loss 1.0147 Accuracy 14.9103
# Epoch 17 Batch 20 Loss 1.0111 Accuracy 14.9027
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.9900
# Epoch 18 Batch 5 Loss 0.9719 Accuracy 14.9037
# Epoch 18 Batch 10 Loss 0.9755 Accuracy 14.9080
# Epoch 18 Batch 15 Loss 1.0104 Accuracy 14.8706
# Epoch 18 Batch 20 Loss 1.0076 Accuracy 14.8637
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.9814
# Epoch 19 Batch 5 Loss 0.9689 Accuracy 14.8651
# Epoch 19 Batch 10 Loss 0.9712 Accuracy 14.8691
# Epoch 19 Batch 15 Loss 1.0062 Accuracy 14.8336
# Epoch 19 Batch 20 Loss 1.0037 Accuracy 14.8272
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.9718
# Epoch 20 Batch 5 Loss 0.9656 Accuracy 14.8287
# Epoch 20 Batch 10 Loss 0.9679 Accuracy 14.8327
# Epoch 20 Batch 15 Loss 1.0028 Accuracy 14.7990
# Epoch 20 Batch 20 Loss 0.9999 Accuracy 14.7928
# Time taken for 1 epoch: 0.15 secs
#
# TestLoss 0.0000 TestAccuracy 13.9613
# Epoch 21 Batch 5 Loss 0.9625 Accuracy 14.7944
# Epoch 21 Batch 10 Loss 0.9634 Accuracy 14.7982
# Epoch 21 Batch 15 Loss 0.9981 Accuracy 14.7660
# Epoch 21 Batch 20 Loss 0.9958 Accuracy 14.7602
# Time taken for 1 epoch: 0.11 secs
#
# TestLoss 0.0000 TestAccuracy 13.9511
# Epoch 22 Batch 5 Loss 0.9591 Accuracy 14.7618
# Epoch 22 Batch 10 Loss 0.9577 Accuracy 14.7653
# Epoch 22 Batch 15 Loss 0.9905 Accuracy 14.7344
# Epoch 22 Batch 20 Loss 0.9898 Accuracy 14.7288
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.9422
# Epoch 23 Batch 5 Loss 0.9552 Accuracy 14.7304
# Epoch 23 Batch 10 Loss 0.9511 Accuracy 14.7333
# Epoch 23 Batch 15 Loss 0.9809 Accuracy 14.7033
# Epoch 23 Batch 20 Loss 0.9827 Accuracy 14.6981
# Time taken for 1 epoch: 0.11 secs
#
# TestLoss 0.0000 TestAccuracy 13.9346
# Epoch 24 Batch 5 Loss 0.9532 Accuracy 14.7000
# Epoch 24 Batch 10 Loss 0.9452 Accuracy 14.7021
# Epoch 24 Batch 15 Loss 0.9696 Accuracy 14.6726
# Epoch 24 Batch 20 Loss 0.9737 Accuracy 14.6673
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.9305
# Epoch 25 Batch 5 Loss 0.9593 Accuracy 14.6704
# Epoch 25 Batch 10 Loss 0.9433 Accuracy 14.6721
# Epoch 25 Batch 15 Loss 0.9627 Accuracy 14.6434
# Epoch 25 Batch 20 Loss 0.9652 Accuracy 14.6366
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.9358
# Epoch 26 Batch 5 Loss 0.9709 Accuracy 14.6405
# Epoch 26 Batch 10 Loss 0.9465 Accuracy 14.6422
# Epoch 26 Batch 15 Loss 0.9650 Accuracy 14.6150
# Epoch 26 Batch 20 Loss 0.9599 Accuracy 14.6065
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.9371
# Epoch 27 Batch 5 Loss 0.9686 Accuracy 14.6099
# Epoch 27 Batch 10 Loss 0.9369 Accuracy 14.6109
# Epoch 27 Batch 15 Loss 0.9608 Accuracy 14.5844
# Epoch 27 Batch 20 Loss 0.9638 Accuracy 14.5780
# Time taken for 1 epoch: 0.17 secs
#
# TestLoss 0.0000 TestAccuracy 13.9263
# Epoch 28 Batch 5 Loss 0.9595 Accuracy 14.5813
# Epoch 28 Batch 10 Loss 0.9383 Accuracy 14.5836
# Epoch 28 Batch 15 Loss 0.9544 Accuracy 14.5582
# Epoch 28 Batch 20 Loss 0.9455 Accuracy 14.5499
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.9544
# Epoch 29 Batch 5 Loss 0.9838 Accuracy 14.5534
# Epoch 29 Batch 10 Loss 0.9389 Accuracy 14.5535
# Epoch 29 Batch 15 Loss 0.9743 Accuracy 14.5308
# Epoch 29 Batch 20 Loss 0.9887 Accuracy 14.5365
# Time taken for 1 epoch: 0.15 secs
#
# TestLoss 0.0000 TestAccuracy 13.9064
# Epoch 30 Batch 5 Loss 0.9218 Accuracy 14.5365
# Epoch 30 Batch 10 Loss 0.9122 Accuracy 14.5316
# Epoch 30 Batch 15 Loss 0.9649 Accuracy 14.5093
# Epoch 30 Batch 20 Loss 0.9612 Accuracy 14.5083
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.8517
# Epoch 31 Batch 5 Loss 0.9597 Accuracy 14.5114
# Epoch 31 Batch 10 Loss 0.9219 Accuracy 14.5083
# Epoch 31 Batch 15 Loss 0.9598 Accuracy 14.4864
# Epoch 31 Batch 20 Loss 0.9698 Accuracy 14.4864
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.8073
# Epoch 32 Batch 5 Loss 0.9786 Accuracy 14.4921
# Epoch 32 Batch 10 Loss 0.9489 Accuracy 14.4931
# Epoch 32 Batch 15 Loss 0.9803 Accuracy 14.4713
# Epoch 32 Batch 20 Loss 0.9691 Accuracy 14.4656
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.7907
# Epoch 33 Batch 5 Loss 0.9343 Accuracy 14.4667
# Epoch 33 Batch 10 Loss 0.9270 Accuracy 14.4707
# Epoch 33 Batch 15 Loss 0.9332 Accuracy 14.4488
# Epoch 33 Batch 20 Loss 0.9461 Accuracy 14.4438
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.8279
# Epoch 34 Batch 5 Loss 0.9623 Accuracy 14.4469
# Epoch 34 Batch 10 Loss 0.9478 Accuracy 14.4501
# Epoch 34 Batch 15 Loss 0.9442 Accuracy 14.4308
# Epoch 34 Batch 20 Loss 0.9350 Accuracy 14.4236
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.8395
# Epoch 35 Batch 5 Loss 0.9399 Accuracy 14.4259
# Epoch 35 Batch 10 Loss 0.9125 Accuracy 14.4267
# Epoch 35 Batch 15 Loss 0.9271 Accuracy 14.4068
# Epoch 35 Batch 20 Loss 0.9246 Accuracy 14.3990
# Time taken for 1 epoch: 0.15 secs
#
# TestLoss 0.0000 TestAccuracy 13.8507
# Epoch 36 Batch 5 Loss 0.9837 Accuracy 14.4042
# Epoch 36 Batch 10 Loss 0.9457 Accuracy 14.4071
# Epoch 36 Batch 15 Loss 0.9535 Accuracy 14.3893
# Epoch 36 Batch 20 Loss 0.9357 Accuracy 14.3807
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.8580
# Epoch 37 Batch 5 Loss 0.9718 Accuracy 14.3851
# Epoch 37 Batch 10 Loss 0.9291 Accuracy 14.3861
# Epoch 37 Batch 15 Loss 0.9467 Accuracy 14.3689
# Epoch 37 Batch 20 Loss 0.9318 Accuracy 14.3601
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.8475
# Epoch 38 Batch 5 Loss 0.9553 Accuracy 14.3628
# Epoch 38 Batch 10 Loss 0.9191 Accuracy 14.3643
# Epoch 38 Batch 15 Loss 0.9340 Accuracy 14.3463
# Epoch 38 Batch 20 Loss 0.9333 Accuracy 14.3399
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.8454
# Epoch 39 Batch 5 Loss 0.8979 Accuracy 14.3389
# Epoch 39 Batch 10 Loss 0.9026 Accuracy 14.3424
# Epoch 39 Batch 15 Loss 0.9046 Accuracy 14.3238
# Epoch 39 Batch 20 Loss 0.9106 Accuracy 14.3175
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.8571
# Epoch 40 Batch 5 Loss 0.9281 Accuracy 14.3192
# Epoch 40 Batch 10 Loss 0.9146 Accuracy 14.3218
# Epoch 40 Batch 15 Loss 0.9219 Accuracy 14.3056
# Epoch 40 Batch 20 Loss 0.9074 Accuracy 14.2984
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.8392
# Epoch 41 Batch 5 Loss 0.9505 Accuracy 14.3019
# Epoch 41 Batch 10 Loss 0.9061 Accuracy 14.3020
# Epoch 41 Batch 15 Loss 0.9405 Accuracy 14.2861
# Epoch 41 Batch 20 Loss 0.9253 Accuracy 14.2791
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.8196
# Epoch 42 Batch 5 Loss 0.9453 Accuracy 14.2823
# Epoch 42 Batch 10 Loss 0.9098 Accuracy 14.2842
# Epoch 42 Batch 15 Loss 0.9318 Accuracy 14.2683
# Epoch 42 Batch 20 Loss 0.9331 Accuracy 14.2642
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.8078
# Epoch 43 Batch 5 Loss 0.8958 Accuracy 14.2638
# Epoch 43 Batch 10 Loss 0.8962 Accuracy 14.2658
# Epoch 43 Batch 15 Loss 0.9056 Accuracy 14.2496
# Epoch 43 Batch 20 Loss 0.8983 Accuracy 14.2447
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.8150
# Epoch 44 Batch 5 Loss 0.9070 Accuracy 14.2452
# Epoch 44 Batch 10 Loss 0.8838 Accuracy 14.2447
# Epoch 44 Batch 15 Loss 0.9224 Accuracy 14.2305
# Epoch 44 Batch 20 Loss 0.9363 Accuracy 14.2329
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.7876
# Epoch 45 Batch 5 Loss 0.9164 Accuracy 14.2343
# Epoch 45 Batch 10 Loss 0.9016 Accuracy 14.2343
# Epoch 45 Batch 15 Loss 0.9663 Accuracy 14.2216
# Epoch 45 Batch 20 Loss 0.9465 Accuracy 14.2179
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.7563
# Epoch 46 Batch 5 Loss 0.9716 Accuracy 14.2208
# Epoch 46 Batch 10 Loss 0.9400 Accuracy 14.2256
# Epoch 46 Batch 15 Loss 0.9784 Accuracy 14.2134
# Epoch 46 Batch 20 Loss 0.9713 Accuracy 14.2111
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.7340
# Epoch 47 Batch 5 Loss 0.8864 Accuracy 14.2099
# Epoch 47 Batch 10 Loss 0.9273 Accuracy 14.2160
# Epoch 47 Batch 15 Loss 0.9410 Accuracy 14.2040
# Epoch 47 Batch 20 Loss 0.9204 Accuracy 14.1973
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.7368
# Epoch 48 Batch 5 Loss 0.9136 Accuracy 14.1985
# Epoch 48 Batch 10 Loss 0.8941 Accuracy 14.2004
# Epoch 48 Batch 15 Loss 0.9026 Accuracy 14.1863
# Epoch 48 Batch 20 Loss 0.8963 Accuracy 14.1796
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.7448
# Epoch 49 Batch 5 Loss 0.8892 Accuracy 14.1789
# Epoch 49 Batch 10 Loss 0.8811 Accuracy 14.1811
# Epoch 49 Batch 15 Loss 0.8878 Accuracy 14.1664
# Epoch 49 Batch 20 Loss 0.8890 Accuracy 14.1609
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.7586
# Epoch 50 Batch 5 Loss 0.8794 Accuracy 14.1605
# Epoch 50 Batch 10 Loss 0.8801 Accuracy 14.1628
# Epoch 50 Batch 15 Loss 0.8867 Accuracy 14.1490
# Epoch 50 Batch 20 Loss 0.8806 Accuracy 14.1425
# Time taken for 1 epoch: 0.11 secs
#
# TestLoss 0.0000 TestAccuracy 13.7559
# Epoch 51 Batch 5 Loss 0.9013 Accuracy 14.1433
# Epoch 51 Batch 10 Loss 0.8795 Accuracy 14.1451
# Epoch 51 Batch 15 Loss 0.8969 Accuracy 14.1317
# Epoch 51 Batch 20 Loss 0.8845 Accuracy 14.1249
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.7614
# Epoch 52 Batch 5 Loss 0.9028 Accuracy 14.1261
# Epoch 52 Batch 10 Loss 0.8832 Accuracy 14.1283
# Epoch 52 Batch 15 Loss 0.9023 Accuracy 14.1158
# Epoch 52 Batch 20 Loss 0.8900 Accuracy 14.1088
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.7605
# Epoch 53 Batch 5 Loss 0.8909 Accuracy 14.1084
# Epoch 53 Batch 10 Loss 0.8885 Accuracy 14.1124
# Epoch 53 Batch 15 Loss 0.9017 Accuracy 14.0996
# Epoch 53 Batch 20 Loss 0.8907 Accuracy 14.0930
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.7746
# Epoch 54 Batch 5 Loss 0.8758 Accuracy 14.0926
# Epoch 54 Batch 10 Loss 0.8747 Accuracy 14.0956
# Epoch 54 Batch 15 Loss 0.8788 Accuracy 14.0830
# Epoch 54 Batch 20 Loss 0.8756 Accuracy 14.0770
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.7894
# Epoch 55 Batch 5 Loss 0.8569 Accuracy 14.0750
# Epoch 55 Batch 10 Loss 0.8683 Accuracy 14.0783
# Epoch 55 Batch 15 Loss 0.8787 Accuracy 14.0657
# Epoch 55 Batch 20 Loss 0.8683 Accuracy 14.0592
# Time taken for 1 epoch: 0.17 secs
#
# TestLoss 0.0000 TestAccuracy 13.8022
# Epoch 56 Batch 5 Loss 0.8802 Accuracy 14.0594
# Epoch 56 Batch 10 Loss 0.8681 Accuracy 14.0614
# Epoch 56 Batch 15 Loss 0.8826 Accuracy 14.0495
# Epoch 56 Batch 20 Loss 0.8745 Accuracy 14.0434
# Time taken for 1 epoch: 0.15 secs
#
# TestLoss 0.0000 TestAccuracy 13.8066
# Epoch 57 Batch 5 Loss 0.8769 Accuracy 14.0429
# Epoch 57 Batch 10 Loss 0.8771 Accuracy 14.0463
# Epoch 57 Batch 15 Loss 0.8927 Accuracy 14.0347
# Epoch 57 Batch 20 Loss 0.8763 Accuracy 14.0278
# Time taken for 1 epoch: 0.15 secs
#
# TestLoss 0.0000 TestAccuracy 13.8166
# Epoch 58 Batch 5 Loss 0.8822 Accuracy 14.0280
# Epoch 58 Batch 10 Loss 0.8710 Accuracy 14.0306
# Epoch 58 Batch 15 Loss 0.8801 Accuracy 14.0190
# Epoch 58 Batch 20 Loss 0.8773 Accuracy 14.0138
# Time taken for 1 epoch: 0.17 secs
#
# TestLoss 0.0000 TestAccuracy 13.8297
# Epoch 59 Batch 5 Loss 0.8498 Accuracy 14.0120
# Epoch 59 Batch 10 Loss 0.8703 Accuracy 14.0156
# Epoch 59 Batch 15 Loss 0.8744 Accuracy 14.0044
# Epoch 59 Batch 20 Loss 0.8580 Accuracy 13.9974
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.8451
# Epoch 60 Batch 5 Loss 0.8905 Accuracy 13.9978
# Epoch 60 Batch 10 Loss 0.8697 Accuracy 13.9997
# Epoch 60 Batch 15 Loss 0.8879 Accuracy 13.9886
# Epoch 60 Batch 20 Loss 0.8875 Accuracy 13.9861
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.8505
# Epoch 61 Batch 5 Loss 0.8776 Accuracy 13.9865
# Epoch 61 Batch 10 Loss 0.8765 Accuracy 13.9887
# Epoch 61 Batch 15 Loss 0.9014 Accuracy 13.9787
# Epoch 61 Batch 20 Loss 0.8774 Accuracy 13.9724
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.8459
# Epoch 62 Batch 5 Loss 0.9187 Accuracy 13.9738
# Epoch 62 Batch 10 Loss 0.9121 Accuracy 13.9784
# Epoch 62 Batch 15 Loss 0.9349 Accuracy 13.9682
# Epoch 62 Batch 20 Loss 0.9283 Accuracy 13.9667
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.8415
# Epoch 63 Batch 5 Loss 0.8900 Accuracy 13.9678
# Epoch 63 Batch 10 Loss 0.9082 Accuracy 13.9723
# Epoch 63 Batch 15 Loss 0.9323 Accuracy 13.9647
# Epoch 63 Batch 20 Loss 0.9037 Accuracy 13.9580
# Time taken for 1 epoch: 0.15 secs
#
# TestLoss 0.0000 TestAccuracy 13.8537
# Epoch 64 Batch 5 Loss 0.8756 Accuracy 13.9579
# Epoch 64 Batch 10 Loss 0.8836 Accuracy 13.9607
# Epoch 64 Batch 15 Loss 0.8694 Accuracy 13.9506
# Epoch 64 Batch 20 Loss 0.8599 Accuracy 13.9443
# Time taken for 1 epoch: 0.17 secs
#
# TestLoss 0.0000 TestAccuracy 13.8641
# Epoch 65 Batch 5 Loss 0.8442 Accuracy 13.9424
# Epoch 65 Batch 10 Loss 0.8515 Accuracy 13.9447
# Epoch 65 Batch 15 Loss 0.8379 Accuracy 13.9330
# Epoch 65 Batch 20 Loss 0.8450 Accuracy 13.9287
# Time taken for 1 epoch: 0.16 secs
#
# TestLoss 0.0000 TestAccuracy 13.8879
# Epoch 66 Batch 5 Loss 0.8418 Accuracy 13.9280
# Epoch 66 Batch 10 Loss 0.8518 Accuracy 13.9298
# Epoch 66 Batch 15 Loss 0.8451 Accuracy 13.9192
# Epoch 66 Batch 20 Loss 0.8394 Accuracy 13.9134
# Time taken for 1 epoch: 0.16 secs
#
# TestLoss 0.0000 TestAccuracy 13.8969
# Epoch 67 Batch 5 Loss 0.8637 Accuracy 13.9133
# Epoch 67 Batch 10 Loss 0.8575 Accuracy 13.9150
# Epoch 67 Batch 15 Loss 0.8595 Accuracy 13.9049
# Epoch 67 Batch 20 Loss 0.8435 Accuracy 13.8984
# Time taken for 1 epoch: 0.16 secs
#
# TestLoss 0.0000 TestAccuracy 13.9080
# Epoch 68 Batch 5 Loss 0.8779 Accuracy 13.8992
# Epoch 68 Batch 10 Loss 0.8619 Accuracy 13.9009
# Epoch 68 Batch 15 Loss 0.8580 Accuracy 13.8906
# Epoch 68 Batch 20 Loss 0.8542 Accuracy 13.8850
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.9148
# Epoch 69 Batch 5 Loss 0.8552 Accuracy 13.8848
# Epoch 69 Batch 10 Loss 0.8689 Accuracy 13.8877
# Epoch 69 Batch 15 Loss 0.8663 Accuracy 13.8790
# Epoch 69 Batch 20 Loss 0.8454 Accuracy 13.8719
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.9241
# Epoch 70 Batch 5 Loss 0.8787 Accuracy 13.8725
# Epoch 70 Batch 10 Loss 0.8600 Accuracy 13.8739
# Epoch 70 Batch 15 Loss 0.8555 Accuracy 13.8640
# Epoch 70 Batch 20 Loss 0.8496 Accuracy 13.8589
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.9332
# Epoch 71 Batch 5 Loss 0.8517 Accuracy 13.8584
# Epoch 71 Batch 10 Loss 0.8673 Accuracy 13.8617
# Epoch 71 Batch 15 Loss 0.8548 Accuracy 13.8522
# Epoch 71 Batch 20 Loss 0.8429 Accuracy 13.8462
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.9428
# Epoch 72 Batch 5 Loss 0.8583 Accuracy 13.8463
# Epoch 72 Batch 10 Loss 0.8491 Accuracy 13.8467
# Epoch 72 Batch 15 Loss 0.8448 Accuracy 13.8368
# Epoch 72 Batch 20 Loss 0.8369 Accuracy 13.8319
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.9287
# Epoch 73 Batch 5 Loss 0.8820 Accuracy 13.8328
# Epoch 73 Batch 10 Loss 0.8776 Accuracy 13.8352
# Epoch 73 Batch 15 Loss 0.8813 Accuracy 13.8268
# Epoch 73 Batch 20 Loss 0.8597 Accuracy 13.8232
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.9098
# Epoch 74 Batch 5 Loss 0.8745 Accuracy 13.8249
# Epoch 74 Batch 10 Loss 0.8647 Accuracy 13.8231
# Epoch 74 Batch 15 Loss 0.8970 Accuracy 13.8153
# Epoch 74 Batch 20 Loss 0.8692 Accuracy 13.8103
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.8888
# Epoch 75 Batch 5 Loss 0.9236 Accuracy 13.8123
# Epoch 75 Batch 10 Loss 0.9024 Accuracy 13.8159
# Epoch 75 Batch 15 Loss 0.8797 Accuracy 13.8062
# Epoch 75 Batch 20 Loss 0.8792 Accuracy 13.8024
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.9174
# Epoch 76 Batch 5 Loss 0.8063 Accuracy 13.8001
# Epoch 76 Batch 10 Loss 0.8443 Accuracy 13.8032
# Epoch 76 Batch 15 Loss 0.8210 Accuracy 13.7944
# Epoch 76 Batch 20 Loss 0.8146 Accuracy 13.7891
# Time taken for 1 epoch: 0.12 secs
#
# TestLoss 0.0000 TestAccuracy 13.9454
# Epoch 77 Batch 5 Loss 0.8207 Accuracy 13.7874
# Epoch 77 Batch 10 Loss 0.8288 Accuracy 13.7887
# Epoch 77 Batch 15 Loss 0.8243 Accuracy 13.7796
# Epoch 77 Batch 20 Loss 0.8162 Accuracy 13.7744
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.9626
# Epoch 78 Batch 5 Loss 0.8435 Accuracy 13.7740
# Epoch 78 Batch 10 Loss 0.8519 Accuracy 13.7761
# Epoch 78 Batch 15 Loss 0.8456 Accuracy 13.7677
# Epoch 78 Batch 20 Loss 0.8309 Accuracy 13.7613
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 13.9714
# Epoch 79 Batch 5 Loss 0.8579 Accuracy 13.7614
# Epoch 79 Batch 10 Loss 0.8562 Accuracy 13.7638
# Epoch 79 Batch 15 Loss 0.8431 Accuracy 13.7553
# Epoch 79 Batch 20 Loss 0.8305 Accuracy 13.7495
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 13.9931
# Epoch 80 Batch 5 Loss 0.8258 Accuracy 13.7483
# Epoch 80 Batch 10 Loss 0.8482 Accuracy 13.7510
# Epoch 80 Batch 15 Loss 0.8258 Accuracy 13.7426
# Epoch 80 Batch 20 Loss 0.8203 Accuracy 13.7364
# Time taken for 1 epoch: 0.14 secs
#
# TestLoss 0.0000 TestAccuracy 14.0113
# Epoch 81 Batch 5 Loss 0.8282 Accuracy 13.7353
# Epoch 81 Batch 10 Loss 0.8441 Accuracy 13.7374
# Epoch 81 Batch 15 Loss 0.8235 Accuracy 13.7293
# Epoch 81 Batch 20 Loss 0.8160 Accuracy 13.7233
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 14.0292
# Epoch 82 Batch 5 Loss 0.8271 Accuracy 13.7223
# Epoch 82 Batch 10 Loss 0.8496 Accuracy 13.7247
# Epoch 82 Batch 15 Loss 0.8271 Accuracy 13.7167
# Epoch 82 Batch 20 Loss 0.8194 Accuracy 13.7107
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 14.0488
# Epoch 83 Batch 5 Loss 0.8325 Accuracy 13.7102
# Epoch 83 Batch 10 Loss 0.8533 Accuracy 13.7127
# Epoch 83 Batch 15 Loss 0.8215 Accuracy 13.7043
# Epoch 83 Batch 20 Loss 0.8263 Accuracy 13.6994
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 14.0759
# Epoch 84 Batch 5 Loss 0.8220 Accuracy 13.6987
# Epoch 84 Batch 10 Loss 0.8528 Accuracy 13.7020
# Epoch 84 Batch 15 Loss 0.8214 Accuracy 13.6937
# Epoch 84 Batch 20 Loss 0.8183 Accuracy 13.6888
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 14.1055
# Epoch 85 Batch 5 Loss 0.8017 Accuracy 13.6871
# Epoch 85 Batch 10 Loss 0.8281 Accuracy 13.6895
# Epoch 85 Batch 15 Loss 0.8135 Accuracy 13.6810
# Epoch 85 Batch 20 Loss 0.8064 Accuracy 13.6762
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 14.1253
# Epoch 86 Batch 5 Loss 0.8208 Accuracy 13.6753
# Epoch 86 Batch 10 Loss 0.8403 Accuracy 13.6779
# Epoch 86 Batch 15 Loss 0.8266 Accuracy 13.6696
# Epoch 86 Batch 20 Loss 0.8181 Accuracy 13.6647
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 14.1459
# Epoch 87 Batch 5 Loss 0.8186 Accuracy 13.6639
# Epoch 87 Batch 10 Loss 0.8403 Accuracy 13.6665
# Epoch 87 Batch 15 Loss 0.8173 Accuracy 13.6584
# Epoch 87 Batch 20 Loss 0.8118 Accuracy 13.6529
# Time taken for 1 epoch: 0.13 secs
#
# TestLoss 0.0000 TestAccuracy 14.1686
# Epoch 88 Batch 5 Loss 0.8155 Accuracy 13.6518
# Epoch 88 Batch 10 Loss 0.8460 Accuracy 13.6547
# Epoch 88 Batch 15 Loss 0.8188 Accuracy 13.6470
# Epoch 88 Batch 20 Loss 0.8109 Accuracy 13.6416
# Time taken for 1 epoch: 0.16 secs
#
# TestLoss 0.0000 TestAccuracy 14.1928
# Epoch 89 Batch 5 Loss 0.8069 Accuracy 13.6404
# Epoch 89 Batch 10 Loss 0.8356 Accuracy 13.6427
# Epoch 89 Batch 15 Loss 0.8063 Accuracy 13.6347
# Epoch 89 Batch 20 Loss 0.8068 Accuracy 13.6297
# Time taken for 1 epoch: 0.16 secs
#
# TestLoss 0.0000 TestAccuracy 14.2173
# Epoch 90 Batch 5 Loss 0.8167 Accuracy 13.6288
# Epoch 90 Batch 10 Loss 0.8511 Accuracy 13.6318
# Epoch 90 Batch 15 Loss 0.8145 Accuracy 13.6239
# Epoch 90 Batch 20 Loss 0.8147 Accuracy 13.6196
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.2428
# Epoch 91 Batch 5 Loss 0.7948 Accuracy 13.6181
# Epoch 91 Batch 10 Loss 0.8253 Accuracy 13.6202
# Epoch 91 Batch 15 Loss 0.8086 Accuracy 13.6126
# Epoch 91 Batch 20 Loss 0.7939 Accuracy 13.6073
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 14.2586
# Epoch 92 Batch 5 Loss 0.8155 Accuracy 13.6063
# Epoch 92 Batch 10 Loss 0.8485 Accuracy 13.6093
# Epoch 92 Batch 15 Loss 0.8362 Accuracy 13.6014
# Epoch 92 Batch 20 Loss 0.8343 Accuracy 13.5987
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 14.2734
# Epoch 93 Batch 5 Loss 0.8234 Accuracy 13.5986
# Epoch 93 Batch 10 Loss 0.8400 Accuracy 13.6008
# Epoch 93 Batch 15 Loss 0.8330 Accuracy 13.5940
# Epoch 93 Batch 20 Loss 0.8135 Accuracy 13.5890
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.2804
# Epoch 94 Batch 5 Loss 0.8556 Accuracy 13.5891
# Epoch 94 Batch 10 Loss 0.8745 Accuracy 13.5931
# Epoch 94 Batch 15 Loss 0.8793 Accuracy 13.5861
# Epoch 94 Batch 20 Loss 0.8717 Accuracy 13.5845
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.2951
# Epoch 95 Batch 5 Loss 0.8168 Accuracy 13.5843
# Epoch 95 Batch 10 Loss 0.8530 Accuracy 13.5875
# Epoch 95 Batch 15 Loss 0.8474 Accuracy 13.5822
# Epoch 95 Batch 20 Loss 0.8219 Accuracy 13.5766
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.3055
# Epoch 96 Batch 5 Loss 0.8285 Accuracy 13.5760
# Epoch 96 Batch 10 Loss 0.8347 Accuracy 13.5778
# Epoch 96 Batch 15 Loss 0.8083 Accuracy 13.5704
# Epoch 96 Batch 20 Loss 0.8015 Accuracy 13.5655
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.3264
# Epoch 97 Batch 5 Loss 0.8063 Accuracy 13.5643
# Epoch 97 Batch 10 Loss 0.8395 Accuracy 13.5668
# Epoch 97 Batch 15 Loss 0.7999 Accuracy 13.5599
# Epoch 97 Batch 20 Loss 0.7995 Accuracy 13.5547
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 14.3505
# Epoch 98 Batch 5 Loss 0.7929 Accuracy 13.5531
# Epoch 98 Batch 10 Loss 0.8347 Accuracy 13.5556
# Epoch 98 Batch 15 Loss 0.7965 Accuracy 13.5488
# Epoch 98 Batch 20 Loss 0.7949 Accuracy 13.5441
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.3795
# Epoch 99 Batch 5 Loss 0.7886 Accuracy 13.5424
# Epoch 99 Batch 10 Loss 0.8294 Accuracy 13.5450
# Epoch 99 Batch 15 Loss 0.7895 Accuracy 13.5377
# Epoch 99 Batch 20 Loss 0.7904 Accuracy 13.5333
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 14.4077
# Epoch 100 Batch 5 Loss 0.7851 Accuracy 13.5316
# Epoch 100 Batch 10 Loss 0.8212 Accuracy 13.5338
# Epoch 100 Batch 15 Loss 0.7871 Accuracy 13.5266
# Epoch 100 Batch 20 Loss 0.7864 Accuracy 13.5223
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.4328
# Epoch 101 Batch 5 Loss 0.7824 Accuracy 13.5204
# Epoch 101 Batch 10 Loss 0.8221 Accuracy 13.5227
# Epoch 101 Batch 15 Loss 0.7948 Accuracy 13.5159
# Epoch 101 Batch 20 Loss 0.7823 Accuracy 13.5108
# Time taken for 1 epoch: 0.35 secs
#
# TestLoss 0.0000 TestAccuracy 14.4535
# Epoch 102 Batch 5 Loss 0.8000 Accuracy 13.5096
# Epoch 102 Batch 10 Loss 0.8298 Accuracy 13.5120
# Epoch 102 Batch 15 Loss 0.8038 Accuracy 13.5048
# Epoch 102 Batch 20 Loss 0.7934 Accuracy 13.5004
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.4720
# Epoch 103 Batch 5 Loss 0.7996 Accuracy 13.4994
# Epoch 103 Batch 10 Loss 0.8286 Accuracy 13.5017
# Epoch 103 Batch 15 Loss 0.7944 Accuracy 13.4947
# Epoch 103 Batch 20 Loss 0.7922 Accuracy 13.4902
# Time taken for 1 epoch: 0.28 secs
#
# TestLoss 0.0000 TestAccuracy 14.4964
# Epoch 104 Batch 5 Loss 0.7780 Accuracy 13.4884
# Epoch 104 Batch 10 Loss 0.8238 Accuracy 13.4909
# Epoch 104 Batch 15 Loss 0.7919 Accuracy 13.4845
# Epoch 104 Batch 20 Loss 0.7816 Accuracy 13.4794
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.5182
# Epoch 105 Batch 5 Loss 0.7884 Accuracy 13.4779
# Epoch 105 Batch 10 Loss 0.8224 Accuracy 13.4801
# Epoch 105 Batch 15 Loss 0.7912 Accuracy 13.4733
# Epoch 105 Batch 20 Loss 0.7804 Accuracy 13.4685
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 14.5387
# Epoch 106 Batch 5 Loss 0.7933 Accuracy 13.4674
# Epoch 106 Batch 10 Loss 0.8279 Accuracy 13.4697
# Epoch 106 Batch 15 Loss 0.7883 Accuracy 13.4627
# Epoch 106 Batch 20 Loss 0.7886 Accuracy 13.4584
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.5634
# Epoch 107 Batch 5 Loss 0.7798 Accuracy 13.4569
# Epoch 107 Batch 10 Loss 0.8265 Accuracy 13.4594
# Epoch 107 Batch 15 Loss 0.7874 Accuracy 13.4532
# Epoch 107 Batch 20 Loss 0.7827 Accuracy 13.4485
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 14.5863
# Epoch 108 Batch 5 Loss 0.7779 Accuracy 13.4468
# Epoch 108 Batch 10 Loss 0.8207 Accuracy 13.4492
# Epoch 108 Batch 15 Loss 0.7883 Accuracy 13.4428
# Epoch 108 Batch 20 Loss 0.7748 Accuracy 13.4381
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 14.6061
# Epoch 109 Batch 5 Loss 0.7904 Accuracy 13.4370
# Epoch 109 Batch 10 Loss 0.8226 Accuracy 13.4392
# Epoch 109 Batch 15 Loss 0.7902 Accuracy 13.4321
# Epoch 109 Batch 20 Loss 0.7885 Accuracy 13.4286
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.6273
# Epoch 110 Batch 5 Loss 0.7850 Accuracy 13.4276
# Epoch 110 Batch 10 Loss 0.8198 Accuracy 13.4297
# Epoch 110 Batch 15 Loss 0.7858 Accuracy 13.4235
# Epoch 110 Batch 20 Loss 0.7794 Accuracy 13.4193
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 14.6468
# Epoch 111 Batch 5 Loss 0.7856 Accuracy 13.4179
# Epoch 111 Batch 10 Loss 0.8175 Accuracy 13.4201
# Epoch 111 Batch 15 Loss 0.8012 Accuracy 13.4142
# Epoch 111 Batch 20 Loss 0.7796 Accuracy 13.4100
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.6558
# Epoch 112 Batch 5 Loss 0.8049 Accuracy 13.4095
# Epoch 112 Batch 10 Loss 0.8230 Accuracy 13.4115
# Epoch 112 Batch 15 Loss 0.8014 Accuracy 13.4049
# Epoch 112 Batch 20 Loss 0.8046 Accuracy 13.4024
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.6792
# Epoch 113 Batch 5 Loss 0.7666 Accuracy 13.4007
# Epoch 113 Batch 10 Loss 0.8206 Accuracy 13.4029
# Epoch 113 Batch 15 Loss 0.8025 Accuracy 13.3984
# Epoch 113 Batch 20 Loss 0.7781 Accuracy 13.3938
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 14.6887
# Epoch 114 Batch 5 Loss 0.8199 Accuracy 13.3940
# Epoch 114 Batch 10 Loss 0.8265 Accuracy 13.3953
# Epoch 114 Batch 15 Loss 0.7968 Accuracy 13.3886
# Epoch 114 Batch 20 Loss 0.7983 Accuracy 13.3860
# Time taken for 1 epoch: 0.28 secs
#
# TestLoss 0.0000 TestAccuracy 14.7066
# Epoch 115 Batch 5 Loss 0.7775 Accuracy 13.3848
# Epoch 115 Batch 10 Loss 0.8227 Accuracy 13.3870
# Epoch 115 Batch 15 Loss 0.7885 Accuracy 13.3821
# Epoch 115 Batch 20 Loss 0.7682 Accuracy 13.3774
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.7258
# Epoch 116 Batch 5 Loss 0.7854 Accuracy 13.3765
# Epoch 116 Batch 10 Loss 0.8172 Accuracy 13.3779
# Epoch 116 Batch 15 Loss 0.7784 Accuracy 13.3713
# Epoch 116 Batch 20 Loss 0.7841 Accuracy 13.3687
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 14.7444
# Epoch 117 Batch 5 Loss 0.7756 Accuracy 13.3672
# Epoch 117 Batch 10 Loss 0.8227 Accuracy 13.3694
# Epoch 117 Batch 15 Loss 0.7867 Accuracy 13.3644
# Epoch 117 Batch 20 Loss 0.7672 Accuracy 13.3599
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 14.7627
# Epoch 118 Batch 5 Loss 0.7847 Accuracy 13.3589
# Epoch 118 Batch 10 Loss 0.8193 Accuracy 13.3607
# Epoch 118 Batch 15 Loss 0.7805 Accuracy 13.3542
# Epoch 118 Batch 20 Loss 0.7848 Accuracy 13.3516
# Time taken for 1 epoch: 0.34 secs
#
# TestLoss 0.0000 TestAccuracy 14.7825
# Epoch 119 Batch 5 Loss 0.7668 Accuracy 13.3499
# Epoch 119 Batch 10 Loss 0.8140 Accuracy 13.3522
# Epoch 119 Batch 15 Loss 0.7813 Accuracy 13.3470
# Epoch 119 Batch 20 Loss 0.7637 Accuracy 13.3426
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 14.7983
# Epoch 120 Batch 5 Loss 0.7889 Accuracy 13.3417
# Epoch 120 Batch 10 Loss 0.8190 Accuracy 13.3436
# Epoch 120 Batch 15 Loss 0.7840 Accuracy 13.3374
# Epoch 120 Batch 20 Loss 0.7824 Accuracy 13.3345
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 14.8179
# Epoch 121 Batch 5 Loss 0.7656 Accuracy 13.3328
# Epoch 121 Batch 10 Loss 0.8123 Accuracy 13.3350
# Epoch 121 Batch 15 Loss 0.7781 Accuracy 13.3299
# Epoch 121 Batch 20 Loss 0.7615 Accuracy 13.3254
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.8351
# Epoch 122 Batch 5 Loss 0.7863 Accuracy 13.3245
# Epoch 122 Batch 10 Loss 0.8169 Accuracy 13.3263
# Epoch 122 Batch 15 Loss 0.7770 Accuracy 13.3202
# Epoch 122 Batch 20 Loss 0.7754 Accuracy 13.3170
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 14.8546
# Epoch 123 Batch 5 Loss 0.7620 Accuracy 13.3153
# Epoch 123 Batch 10 Loss 0.8138 Accuracy 13.3175
# Epoch 123 Batch 15 Loss 0.7737 Accuracy 13.3126
# Epoch 123 Batch 20 Loss 0.7606 Accuracy 13.3080
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.8738
# Epoch 124 Batch 5 Loss 0.7736 Accuracy 13.3068
# Epoch 124 Batch 10 Loss 0.8141 Accuracy 13.3087
# Epoch 124 Batch 15 Loss 0.7692 Accuracy 13.3028
# Epoch 124 Batch 20 Loss 0.7682 Accuracy 13.2995
# Time taken for 1 epoch: 0.34 secs
#
# TestLoss 0.0000 TestAccuracy 14.8935
# Epoch 125 Batch 5 Loss 0.7623 Accuracy 13.2980
# Epoch 125 Batch 10 Loss 0.8127 Accuracy 13.3000
# Epoch 125 Batch 15 Loss 0.7652 Accuracy 13.2949
# Epoch 125 Batch 20 Loss 0.7594 Accuracy 13.2907
# Time taken for 1 epoch: 0.35 secs
#
# TestLoss 0.0000 TestAccuracy 14.9145
# Epoch 126 Batch 5 Loss 0.7620 Accuracy 13.2892
# Epoch 126 Batch 10 Loss 0.8115 Accuracy 13.2912
# Epoch 126 Batch 15 Loss 0.7671 Accuracy 13.2857
# Epoch 126 Batch 20 Loss 0.7639 Accuracy 13.2824
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 14.9336
# Epoch 127 Batch 5 Loss 0.7632 Accuracy 13.2809
# Epoch 127 Batch 10 Loss 0.8101 Accuracy 13.2828
# Epoch 127 Batch 15 Loss 0.7620 Accuracy 13.2775
# Epoch 127 Batch 20 Loss 0.7568 Accuracy 13.2735
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 14.9548
# Epoch 128 Batch 5 Loss 0.7649 Accuracy 13.2723
# Epoch 128 Batch 10 Loss 0.8125 Accuracy 13.2742
# Epoch 128 Batch 15 Loss 0.7655 Accuracy 13.2686
# Epoch 128 Batch 20 Loss 0.7661 Accuracy 13.2657
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 14.9753
# Epoch 129 Batch 5 Loss 0.7565 Accuracy 13.2641
# Epoch 129 Batch 10 Loss 0.8078 Accuracy 13.2660
# Epoch 129 Batch 15 Loss 0.7600 Accuracy 13.2610
# Epoch 129 Batch 20 Loss 0.7523 Accuracy 13.2570
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 14.9963
# Epoch 130 Batch 5 Loss 0.7644 Accuracy 13.2558
# Epoch 130 Batch 10 Loss 0.8107 Accuracy 13.2577
# Epoch 130 Batch 15 Loss 0.7681 Accuracy 13.2521
# Epoch 130 Batch 20 Loss 0.7642 Accuracy 13.2493
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 15.0148
# Epoch 131 Batch 5 Loss 0.7658 Accuracy 13.2481
# Epoch 131 Batch 10 Loss 0.8052 Accuracy 13.2499
# Epoch 131 Batch 15 Loss 0.7616 Accuracy 13.2447
# Epoch 131 Batch 20 Loss 0.7543 Accuracy 13.2409
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 15.0347
# Epoch 132 Batch 5 Loss 0.7655 Accuracy 13.2398
# Epoch 132 Batch 10 Loss 0.8068 Accuracy 13.2415
# Epoch 132 Batch 15 Loss 0.7656 Accuracy 13.2362
# Epoch 132 Batch 20 Loss 0.7593 Accuracy 13.2331
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 15.0532
# Epoch 133 Batch 5 Loss 0.7602 Accuracy 13.2317
# Epoch 133 Batch 10 Loss 0.8057 Accuracy 13.2335
# Epoch 133 Batch 15 Loss 0.7628 Accuracy 13.2287
# Epoch 133 Batch 20 Loss 0.7508 Accuracy 13.2246
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.0715
# Epoch 134 Batch 5 Loss 0.7730 Accuracy 13.2237
# Epoch 134 Batch 10 Loss 0.8098 Accuracy 13.2254
# Epoch 134 Batch 15 Loss 0.7630 Accuracy 13.2199
# Epoch 134 Batch 20 Loss 0.7627 Accuracy 13.2171
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 15.0925
# Epoch 135 Batch 5 Loss 0.7549 Accuracy 13.2159
# Epoch 135 Batch 10 Loss 0.8087 Accuracy 13.2178
# Epoch 135 Batch 15 Loss 0.7609 Accuracy 13.2133
# Epoch 135 Batch 20 Loss 0.7520 Accuracy 13.2094
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 15.1115
# Epoch 136 Batch 5 Loss 0.7629 Accuracy 13.2083
# Epoch 136 Batch 10 Loss 0.8042 Accuracy 13.2101
# Epoch 136 Batch 15 Loss 0.7663 Accuracy 13.2050
# Epoch 136 Batch 20 Loss 0.7549 Accuracy 13.2019
# Time taken for 1 epoch: 0.28 secs
#
# TestLoss 0.0000 TestAccuracy 15.1272
# Epoch 137 Batch 5 Loss 0.7731 Accuracy 13.2012
# Epoch 137 Batch 10 Loss 0.8077 Accuracy 13.2030
# Epoch 137 Batch 15 Loss 0.7707 Accuracy 13.1979
# Epoch 137 Batch 20 Loss 0.7607 Accuracy 13.1945
# Time taken for 1 epoch: 0.37 secs
#
# TestLoss 0.0000 TestAccuracy 15.1468
# Epoch 138 Batch 5 Loss 0.7640 Accuracy 13.1936
# Epoch 138 Batch 10 Loss 0.8026 Accuracy 13.1953
# Epoch 138 Batch 15 Loss 0.7624 Accuracy 13.1906
# Epoch 138 Batch 20 Loss 0.7521 Accuracy 13.1871
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.1654
# Epoch 139 Batch 5 Loss 0.7626 Accuracy 13.1860
# Epoch 139 Batch 10 Loss 0.8016 Accuracy 13.1877
# Epoch 139 Batch 15 Loss 0.7658 Accuracy 13.1833
# Epoch 139 Batch 20 Loss 0.7463 Accuracy 13.1792
# Time taken for 1 epoch: 0.28 secs
#
# TestLoss 0.0000 TestAccuracy 15.1808
# Epoch 140 Batch 5 Loss 0.7799 Accuracy 13.1789
# Epoch 140 Batch 10 Loss 0.8085 Accuracy 13.1805
# Epoch 140 Batch 15 Loss 0.7680 Accuracy 13.1753
# Epoch 140 Batch 20 Loss 0.7715 Accuracy 13.1732
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.2032
# Epoch 141 Batch 5 Loss 0.7496 Accuracy 13.1721
# Epoch 141 Batch 10 Loss 0.8098 Accuracy 13.1741
# Epoch 141 Batch 15 Loss 0.7674 Accuracy 13.1704
# Epoch 141 Batch 20 Loss 0.7509 Accuracy 13.1667
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.2175
# Epoch 142 Batch 5 Loss 0.7573 Accuracy 13.1656
# Epoch 142 Batch 10 Loss 0.8034 Accuracy 13.1674
# Epoch 142 Batch 15 Loss 0.7641 Accuracy 13.1624
# Epoch 142 Batch 20 Loss 0.7572 Accuracy 13.1601
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.2302
# Epoch 143 Batch 5 Loss 0.7636 Accuracy 13.1593
# Epoch 143 Batch 10 Loss 0.8014 Accuracy 13.1611
# Epoch 143 Batch 15 Loss 0.7628 Accuracy 13.1564
# Epoch 143 Batch 20 Loss 0.7597 Accuracy 13.1536
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.2499
# Epoch 144 Batch 5 Loss 0.7471 Accuracy 13.1522
# Epoch 144 Batch 10 Loss 0.7959 Accuracy 13.1537
# Epoch 144 Batch 15 Loss 0.7592 Accuracy 13.1498
# Epoch 144 Batch 20 Loss 0.7430 Accuracy 13.1464
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 15.2621
# Epoch 145 Batch 5 Loss 0.7620 Accuracy 13.1455
# Epoch 145 Batch 10 Loss 0.8073 Accuracy 13.1472
# Epoch 145 Batch 15 Loss 0.7645 Accuracy 13.1425
# Epoch 145 Batch 20 Loss 0.7578 Accuracy 13.1395
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 15.2770
# Epoch 146 Batch 5 Loss 0.7527 Accuracy 13.1384
# Epoch 146 Batch 10 Loss 0.8071 Accuracy 13.1403
# Epoch 146 Batch 15 Loss 0.7554 Accuracy 13.1361
# Epoch 146 Batch 20 Loss 0.7529 Accuracy 13.1331
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.2951
# Epoch 147 Batch 5 Loss 0.7416 Accuracy 13.1315
# Epoch 147 Batch 10 Loss 0.8066 Accuracy 13.1333
# Epoch 147 Batch 15 Loss 0.7531 Accuracy 13.1291
# Epoch 147 Batch 20 Loss 0.7470 Accuracy 13.1259
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.3107
# Epoch 148 Batch 5 Loss 0.7560 Accuracy 13.1248
# Epoch 148 Batch 10 Loss 0.8109 Accuracy 13.1264
# Epoch 148 Batch 15 Loss 0.7547 Accuracy 13.1219
# Epoch 148 Batch 20 Loss 0.7619 Accuracy 13.1198
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 15.3275
# Epoch 149 Batch 5 Loss 0.7424 Accuracy 13.1184
# Epoch 149 Batch 10 Loss 0.8021 Accuracy 13.1200
# Epoch 149 Batch 15 Loss 0.7579 Accuracy 13.1159
# Epoch 149 Batch 20 Loss 0.7445 Accuracy 13.1128
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.3312
# Epoch 150 Batch 5 Loss 0.7714 Accuracy 13.1122
# Epoch 150 Batch 10 Loss 0.8153 Accuracy 13.1140
# Epoch 150 Batch 15 Loss 0.7816 Accuracy 13.1092
# Epoch 150 Batch 20 Loss 0.7753 Accuracy 13.1074
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 15.3390
# Epoch 151 Batch 5 Loss 0.7607 Accuracy 13.1067
# Epoch 151 Batch 10 Loss 0.7998 Accuracy 13.1085
# Epoch 151 Batch 15 Loss 0.7575 Accuracy 13.1044
# Epoch 151 Batch 20 Loss 0.7431 Accuracy 13.1007
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.3488
# Epoch 152 Batch 5 Loss 0.7784 Accuracy 13.1004
# Epoch 152 Batch 10 Loss 0.7959 Accuracy 13.1014
# Epoch 152 Batch 15 Loss 0.7508 Accuracy 13.0968
# Epoch 152 Batch 20 Loss 0.7485 Accuracy 13.0942
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.3619
# Epoch 153 Batch 5 Loss 0.7456 Accuracy 13.0930
# Epoch 153 Batch 10 Loss 0.8029 Accuracy 13.0945
# Epoch 153 Batch 15 Loss 0.7598 Accuracy 13.0912
# Epoch 153 Batch 20 Loss 0.7412 Accuracy 13.0875
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 15.3735
# Epoch 154 Batch 5 Loss 0.7721 Accuracy 13.0871
# Epoch 154 Batch 10 Loss 0.8029 Accuracy 13.0884
# Epoch 154 Batch 15 Loss 0.7544 Accuracy 13.0836
# Epoch 154 Batch 20 Loss 0.7548 Accuracy 13.0815
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 15.3869
# Epoch 155 Batch 5 Loss 0.7674 Accuracy 13.0811
# Epoch 155 Batch 10 Loss 0.8022 Accuracy 13.0826
# Epoch 155 Batch 15 Loss 0.7513 Accuracy 13.0786
# Epoch 155 Batch 20 Loss 0.7424 Accuracy 13.0755
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.3992
# Epoch 156 Batch 5 Loss 0.7651 Accuracy 13.0748
# Epoch 156 Batch 10 Loss 0.7934 Accuracy 13.0758
# Epoch 156 Batch 15 Loss 0.7611 Accuracy 13.0717
# Epoch 156 Batch 20 Loss 0.7463 Accuracy 13.0696
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 15.3976
# Epoch 157 Batch 5 Loss 0.7652 Accuracy 13.0690
# Epoch 157 Batch 10 Loss 0.8017 Accuracy 13.0704
# Epoch 157 Batch 15 Loss 0.7676 Accuracy 13.0663
# Epoch 157 Batch 20 Loss 0.7588 Accuracy 13.0635
# Time taken for 1 epoch: 0.29 secs
#
# TestLoss 0.0000 TestAccuracy 15.4036
# Epoch 158 Batch 5 Loss 0.7679 Accuracy 13.0629
# Epoch 158 Batch 10 Loss 0.8016 Accuracy 13.0643
# Epoch 158 Batch 15 Loss 0.7601 Accuracy 13.0603
# Epoch 158 Batch 20 Loss 0.7481 Accuracy 13.0578
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.4125
# Epoch 159 Batch 5 Loss 0.7611 Accuracy 13.0570
# Epoch 159 Batch 10 Loss 0.8000 Accuracy 13.0585
# Epoch 159 Batch 15 Loss 0.7525 Accuracy 13.0545
# Epoch 159 Batch 20 Loss 0.7455 Accuracy 13.0511
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.4223
# Epoch 160 Batch 5 Loss 0.7452 Accuracy 13.0502
# Epoch 160 Batch 10 Loss 0.7903 Accuracy 13.0515
# Epoch 160 Batch 15 Loss 0.7385 Accuracy 13.0477
# Epoch 160 Batch 20 Loss 0.7355 Accuracy 13.0450
# Time taken for 1 epoch: 0.31 secs
# TestLoss 0.0000 TestAccuracy 15.4379
# Epoch 161 Batch 5 Loss 0.7386 Accuracy 13.0437
# Epoch 161 Batch 10 Loss 0.8017 Accuracy 13.0454
# Epoch 161 Batch 15 Loss 0.7412 Accuracy 13.0415
# Epoch 161 Batch 20 Loss 0.7398 Accuracy 13.0388
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.4572
# Epoch 162 Batch 5 Loss 0.7509 Accuracy 13.0380
# Epoch 162 Batch 10 Loss 0.7891 Accuracy 13.0395
# Epoch 162 Batch 15 Loss 0.7352 Accuracy 13.0352
# Epoch 162 Batch 20 Loss 0.7393 Accuracy 13.0331
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.4763
# Epoch 163 Batch 5 Loss 0.7313 Accuracy 13.0317
# Epoch 163 Batch 10 Loss 0.7854 Accuracy 13.0331
# Epoch 163 Batch 15 Loss 0.7388 Accuracy 13.0293
# Epoch 163 Batch 20 Loss 0.7273 Accuracy 13.0263
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 15.4886
# Epoch 164 Batch 5 Loss 0.7577 Accuracy 13.0255
# Epoch 164 Batch 10 Loss 0.8016 Accuracy 13.0271
# Epoch 164 Batch 15 Loss 0.7598 Accuracy 13.0229
# Epoch 164 Batch 20 Loss 0.7543 Accuracy 13.0211
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.5031
# Epoch 165 Batch 5 Loss 0.7409 Accuracy 13.0201
# Epoch 165 Batch 10 Loss 0.7875 Accuracy 13.0217
# Epoch 165 Batch 15 Loss 0.7373 Accuracy 13.0180
# Epoch 165 Batch 20 Loss 0.7284 Accuracy 13.0146
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.5171
# Epoch 166 Batch 5 Loss 0.7493 Accuracy 13.0137
# Epoch 166 Batch 10 Loss 0.7897 Accuracy 13.0150
# Epoch 166 Batch 15 Loss 0.7325 Accuracy 13.0108
# Epoch 166 Batch 20 Loss 0.7329 Accuracy 13.0084
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 15.5341
# Epoch 167 Batch 5 Loss 0.7361 Accuracy 13.0072
# Epoch 167 Batch 10 Loss 0.7965 Accuracy 13.0087
# Epoch 167 Batch 15 Loss 0.7395 Accuracy 13.0052
# Epoch 167 Batch 20 Loss 0.7332 Accuracy 13.0023
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 15.5500
# Epoch 168 Batch 5 Loss 0.7434 Accuracy 13.0013
# Epoch 168 Batch 10 Loss 0.7954 Accuracy 13.0031
# Epoch 168 Batch 15 Loss 0.7445 Accuracy 12.9988
# Epoch 168 Batch 20 Loss 0.7429 Accuracy 12.9971
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 15.5648
# Epoch 169 Batch 5 Loss 0.7474 Accuracy 12.9963
# Epoch 169 Batch 10 Loss 0.7787 Accuracy 12.9975
# Epoch 169 Batch 15 Loss 0.7332 Accuracy 12.9936
# Epoch 169 Batch 20 Loss 0.7303 Accuracy 12.9911
# Time taken for 1 epoch: 0.34 secs
#
# TestLoss 0.0000 TestAccuracy 15.5805
# Epoch 170 Batch 5 Loss 0.7307 Accuracy 12.9900
# Epoch 170 Batch 10 Loss 0.7775 Accuracy 12.9911
# Epoch 170 Batch 15 Loss 0.7352 Accuracy 12.9879
# Epoch 170 Batch 20 Loss 0.7214 Accuracy 12.9848
# Time taken for 1 epoch: 0.35 secs
#
# TestLoss 0.0000 TestAccuracy 15.5927
# Epoch 171 Batch 5 Loss 0.7582 Accuracy 12.9843
# Epoch 171 Batch 10 Loss 0.7863 Accuracy 12.9853
# Epoch 171 Batch 15 Loss 0.7396 Accuracy 12.9816
# Epoch 171 Batch 20 Loss 0.7280 Accuracy 12.9788
# Time taken for 1 epoch: 0.34 secs
#
# TestLoss 0.0000 TestAccuracy 15.6060
# Epoch 172 Batch 5 Loss 0.7452 Accuracy 12.9781
# Epoch 172 Batch 10 Loss 0.7895 Accuracy 12.9792
# Epoch 172 Batch 15 Loss 0.7341 Accuracy 12.9757
# Epoch 172 Batch 20 Loss 0.7300 Accuracy 12.9727
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.6198
# Epoch 173 Batch 5 Loss 0.7506 Accuracy 12.9720
# Epoch 173 Batch 10 Loss 0.7956 Accuracy 12.9735
# Epoch 173 Batch 15 Loss 0.7377 Accuracy 12.9698
# Epoch 173 Batch 20 Loss 0.7388 Accuracy 12.9680
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 15.6339
# Epoch 174 Batch 5 Loss 0.7291 Accuracy 12.9667
# Epoch 174 Batch 10 Loss 0.7812 Accuracy 12.9680
# Epoch 174 Batch 15 Loss 0.7228 Accuracy 12.9643
# Epoch 174 Batch 20 Loss 0.7233 Accuracy 12.9617
# Time taken for 1 epoch: 0.33 secs
#
# TestLoss 0.0000 TestAccuracy 15.6507
# Epoch 175 Batch 5 Loss 0.7379 Accuracy 12.9609
# Epoch 175 Batch 10 Loss 0.7886 Accuracy 12.9621
# Epoch 175 Batch 15 Loss 0.7310 Accuracy 12.9584
# Epoch 175 Batch 20 Loss 0.7367 Accuracy 12.9569
# Time taken for 1 epoch: 0.33 secs
#
# TestLoss 0.0000 TestAccuracy 15.6668
# Epoch 176 Batch 5 Loss 0.7215 Accuracy 12.9554
# Epoch 176 Batch 10 Loss 0.7801 Accuracy 12.9566
# Epoch 176 Batch 15 Loss 0.7217 Accuracy 12.9531
# Epoch 176 Batch 20 Loss 0.7187 Accuracy 12.9509
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 15.6830
# Epoch 177 Batch 5 Loss 0.7281 Accuracy 12.9497
# Epoch 177 Batch 10 Loss 0.7829 Accuracy 12.9508
# Epoch 177 Batch 15 Loss 0.7285 Accuracy 12.9470
# Epoch 177 Batch 20 Loss 0.7270 Accuracy 12.9452
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.6987
# Epoch 178 Batch 5 Loss 0.7333 Accuracy 12.9442
# Epoch 178 Batch 10 Loss 0.7842 Accuracy 12.9455
# Epoch 178 Batch 15 Loss 0.7264 Accuracy 12.9417
# Epoch 178 Batch 20 Loss 0.7251 Accuracy 12.9397
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 15.7148
# Epoch 179 Batch 5 Loss 0.7240 Accuracy 12.9385
# Epoch 179 Batch 10 Loss 0.7823 Accuracy 12.9397
# Epoch 179 Batch 15 Loss 0.7220 Accuracy 12.9362
# Epoch 179 Batch 20 Loss 0.7200 Accuracy 12.9336
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.7305
# Epoch 180 Batch 5 Loss 0.7374 Accuracy 12.9328
# Epoch 180 Batch 10 Loss 0.7839 Accuracy 12.9341
# Epoch 180 Batch 15 Loss 0.7243 Accuracy 12.9302
# Epoch 180 Batch 20 Loss 0.7294 Accuracy 12.9287
# Time taken for 1 epoch: 0.35 secs
#
# TestLoss 0.0000 TestAccuracy 15.7466
# Epoch 181 Batch 5 Loss 0.7192 Accuracy 12.9276
# Epoch 181 Batch 10 Loss 0.7816 Accuracy 12.9288
# Epoch 181 Batch 15 Loss 0.7212 Accuracy 12.9253
# Epoch 181 Batch 20 Loss 0.7210 Accuracy 12.9231
# Time taken for 1 epoch: 0.33 secs
#
# TestLoss 0.0000 TestAccuracy 15.7635
# Epoch 182 Batch 5 Loss 0.7352 Accuracy 12.9223
# Epoch 182 Batch 10 Loss 0.7727 Accuracy 12.9232
# Epoch 182 Batch 15 Loss 0.7225 Accuracy 12.9196
# Epoch 182 Batch 20 Loss 0.7183 Accuracy 12.9177
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 15.7807
# Epoch 183 Batch 5 Loss 0.7328 Accuracy 12.9168
# Epoch 183 Batch 10 Loss 0.7783 Accuracy 12.9178
# Epoch 183 Batch 15 Loss 0.7306 Accuracy 12.9146
# Epoch 183 Batch 20 Loss 0.7159 Accuracy 12.9118
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.7927
# Epoch 184 Batch 5 Loss 0.7507 Accuracy 12.9114
# Epoch 184 Batch 10 Loss 0.7801 Accuracy 12.9123
# Epoch 184 Batch 15 Loss 0.7324 Accuracy 12.9089
# Epoch 184 Batch 20 Loss 0.7265 Accuracy 12.9067
# Time taken for 1 epoch: 0.33 secs
#
# TestLoss 0.0000 TestAccuracy 15.8084
# Epoch 185 Batch 5 Loss 0.7286 Accuracy 12.9060
# Epoch 185 Batch 10 Loss 0.7854 Accuracy 12.9070
# Epoch 185 Batch 15 Loss 0.7259 Accuracy 12.9040
# Epoch 185 Batch 20 Loss 0.7204 Accuracy 12.9016
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.8217
# Epoch 186 Batch 5 Loss 0.7375 Accuracy 12.9009
# Epoch 186 Batch 10 Loss 0.7793 Accuracy 12.9021
# Epoch 186 Batch 15 Loss 0.7367 Accuracy 12.8985
# Epoch 186 Batch 20 Loss 0.7307 Accuracy 12.8971
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 15.8323
# Epoch 187 Batch 5 Loss 0.7383 Accuracy 12.8965
# Epoch 187 Batch 10 Loss 0.7825 Accuracy 12.8979
# Epoch 187 Batch 15 Loss 0.7346 Accuracy 12.8942
# Epoch 187 Batch 20 Loss 0.7454 Accuracy 12.8932
# Time taken for 1 epoch: 0.33 secs
#
# TestLoss 0.0000 TestAccuracy 15.8516
# Epoch 188 Batch 5 Loss 0.7040 Accuracy 12.8917
# Epoch 188 Batch 10 Loss 0.7735 Accuracy 12.8931
# Epoch 188 Batch 15 Loss 0.7172 Accuracy 12.8903
# Epoch 188 Batch 20 Loss 0.7109 Accuracy 12.8883
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.8658
# Epoch 189 Batch 5 Loss 0.7119 Accuracy 12.8870
# Epoch 189 Batch 10 Loss 0.7655 Accuracy 12.8877
# Epoch 189 Batch 15 Loss 0.7100 Accuracy 12.8844
# Epoch 189 Batch 20 Loss 0.7071 Accuracy 12.8823
# Time taken for 1 epoch: 0.30 secs
#
# TestLoss 0.0000 TestAccuracy 15.8778
# Epoch 190 Batch 5 Loss 0.7289 Accuracy 12.8815
# Epoch 190 Batch 10 Loss 0.7857 Accuracy 12.8824
# Epoch 190 Batch 15 Loss 0.7229 Accuracy 12.8794
# Epoch 190 Batch 20 Loss 0.7279 Accuracy 12.8775
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.8910
# Epoch 191 Batch 5 Loss 0.7397 Accuracy 12.8766
# Epoch 191 Batch 10 Loss 0.7809 Accuracy 12.8776
# Epoch 191 Batch 15 Loss 0.7348 Accuracy 12.8743
# Epoch 191 Batch 20 Loss 0.7301 Accuracy 12.8731
# Time taken for 1 epoch: 0.33 secs
#
# TestLoss 0.0000 TestAccuracy 15.8964
# Epoch 192 Batch 5 Loss 0.7402 Accuracy 12.8724
# Epoch 192 Batch 10 Loss 0.7836 Accuracy 12.8736
# Epoch 192 Batch 15 Loss 0.7341 Accuracy 12.8701
# Epoch 192 Batch 20 Loss 0.7473 Accuracy 12.8694
# Time taken for 1 epoch: 0.34 secs
#
# TestLoss 0.0000 TestAccuracy 15.9102
# Epoch 193 Batch 5 Loss 0.7277 Accuracy 12.8685
# Epoch 193 Batch 10 Loss 0.7941 Accuracy 12.8696
# Epoch 193 Batch 15 Loss 0.7363 Accuracy 12.8669
# Epoch 193 Batch 20 Loss 0.7295 Accuracy 12.8658
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 15.9113
# Epoch 194 Batch 5 Loss 0.7372 Accuracy 12.8651
# Epoch 194 Batch 10 Loss 0.7775 Accuracy 12.8659
# Epoch 194 Batch 15 Loss 0.7269 Accuracy 12.8621
# Epoch 194 Batch 20 Loss 0.7379 Accuracy 12.8616
# Time taken for 1 epoch: 0.33 secs
#
# TestLoss 0.0000 TestAccuracy 15.9148
# Epoch 195 Batch 5 Loss 0.7366 Accuracy 12.8610
# Epoch 195 Batch 10 Loss 0.7922 Accuracy 12.8620
# Epoch 195 Batch 15 Loss 0.7347 Accuracy 12.8593
# Epoch 195 Batch 20 Loss 0.7263 Accuracy 12.8572
# Time taken for 1 epoch: 0.38 secs
#
# TestLoss 0.0000 TestAccuracy 15.9189
# Epoch 196 Batch 5 Loss 0.7436 Accuracy 12.8567
# Epoch 196 Batch 10 Loss 0.7837 Accuracy 12.8578
# Epoch 196 Batch 15 Loss 0.7381 Accuracy 12.8543
# Epoch 196 Batch 20 Loss 0.7372 Accuracy 12.8531
# Time taken for 1 epoch: 0.32 secs
#
# TestLoss 0.0000 TestAccuracy 15.9262
# Epoch 197 Batch 5 Loss 0.7309 Accuracy 12.8523
# Epoch 197 Batch 10 Loss 0.7838 Accuracy 12.8532
# Epoch 197 Batch 15 Loss 0.7154 Accuracy 12.8504
# Epoch 197 Batch 20 Loss 0.7209 Accuracy 12.8487
# Time taken for 1 epoch: 0.31 secs
#
# TestLoss 0.0000 TestAccuracy 15.9401
# Epoch 198 Batch 5 Loss 0.7122 Accuracy 12.8476
# Epoch 198 Batch 10 Loss 0.7890 Accuracy 12.8487
# Epoch 198 Batch 15 Loss 0.7256 Accuracy 12.8456
# Epoch 198 Batch 20 Loss 0.7290 Accuracy 12.8451
# Time taken for 1 epoch: 0.33 secs
#
# TestLoss 0.0000 TestAccuracy 15.9490
# Epoch 199 Batch 5 Loss 0.7137 Accuracy 12.8441
# Epoch 199 Batch 10 Loss 0.7690 Accuracy 12.8447
# Epoch 199 Batch 15 Loss 0.7093 Accuracy 12.8419
# Epoch 199 Batch 20 Loss 0.7074 Accuracy 12.8395
# Time taken for 1 epoch: 0.33 secs
#
# TestLoss 0.0000 TestAccuracy 15.9635
# Epoch 200 Batch 5 Loss 0.7488 Accuracy 12.8392
# Epoch 200 Batch 10 Loss 0.7815 Accuracy 12.8403
# Epoch 200 Batch 15 Loss 0.7248 Accuracy 12.8369
# Epoch 200 Batch 20 Loss 0.7275 Accuracy 12.8358
# Time taken for 1 epoch: 0.36 secs
#
# TestLoss 0.0000 TestAccuracy 15.9721

# %% [markdown]
# 결론 : 동일한 구조와 동일한 Loss값(MeanSquaredError)를 주었을 때 나리플로우와 텐서플로우는 모두 비슷한 수준으로 훈련 LOSS가 줄어든다.
